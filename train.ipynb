# %%
import os
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count=10'

import jax
import jax.random as jr
import jax.numpy as jnp
from utils import *
from main import run_experiment
from environments.harmonic_oscillator import HarmonicOscillator
import numpy as np
import matplotlib.pyplot as plt

device = jax.devices()[0].platform
print(f"Using device: {device}")
# Out:
# These device(s) are detected:  [CpuDevice(id=0), CpuDevice(id=1), CpuDevice(id=2), CpuDevice(id=3), CpuDevice(id=4), CpuDevice(id=5), CpuDevice(id=6), CpuDevice(id=7), CpuDevice(id=8), CpuDevice(id=9)]
# Using device: cpu

# %%
# def distance_feedback(x, target):
#     return jnp.abs(target - x[0])
def distance_feedback(x, target):
    err = x[0] - target
    return 0.5 * err**2

def direction_feedback(x, target):
    return target - x[0]


args = {
    "param_setting": "constant",
    "batch_size": 16,
    "n_obs": 2,
    "process_noise": 0.05,
    "obs_noise": 0.3,
    "num_generations": 50,
    "population_size": 100,
    "num_populations": 10
}

save_path = 'results/harmonic_oscillator/full_obs/tpse_feedback'
os.makedirs(save_path, exist_ok=True)

# %%
strategy, best_fitnesses = run_experiment(args, feedback_fn=distance_feedback, save_path=save_path, device=device)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'a0', 'a1', 'u0', 'e'].
# Compiling code for evaluation and evolution...
# Finished compilation in 33.83 seconds
# In generation 1
# Complexity: 5, fitness: 4.308530330657959, equations: [0.379, -0.332*a1, 0.594]
# Complexity: 7, fitness: 3.9842798709869385, equations: [0.342, y1 + 0.307, 0.0707]
# Complexity: 11, fitness: 3.0999324321746826, equations: [u0 - 0.0641, 3.53, 0.18*e]
# Complexity: 15, fitness: 3.0917246341705322, equations: [e + u0 - 0.63, e*(0.0561*a0 + 0.0125), 0.27*e]
# Complexity: 17, fitness: 2.9524590969085693, equations: [0.582*a1, 0.0706 - a1, 0.103*a0*(2.49*e + 0.394)]
# Complexity: 19, fitness: 1.7171045541763306, equations: [-1.38*a0 + u0 + y1 - 0.00483, -a1 + e, -1.55*a0 + 1.55*e - 0.374]
# In generation 2
# Complexity: 3, fitness: 4.005646228790283, equations: [-0.485, -0.00281, 0.212]
# Complexity: 5, fitness: 3.9900834560394287, equations: [-1.64, -7.04*y1, 0.149]
# Complexity: 7, fitness: 3.9461681842803955, equations: [-1.58, -0.197/a1, 0.00394*e]
# Complexity: 9, fitness: 3.8543646335601807, equations: [0.127*a1*y1, -0.169*y1, a1]
# Complexity: 11, fitness: 3.0594699382781982, equations: [0.531, 0.339 - 2.24*a1, 1.1*a1*e]
# Complexity: 13, fitness: 2.9817373752593994, equations: [-4.12*u0 - 1.02, 0.777, a0 + a1 + e + 0.364]
# Complexity: 17, fitness: 2.9524590969085693, equations: [0.582*a1, 0.0706 - a1, 0.103*a0*(2.49*e + 0.394)]
# Complexity: 19, fitness: 1.7171045541763306, equations: [-1.38*a0 + u0 + y1 - 0.00483, -a1 + e, -1.55*a0 + 1.55*e - 0.374]
# In generation 3
# Complexity: 3, fitness: 3.9902639389038086, equations: [-0.806, -0.692, 0.00896]
# Complexity: 5, fitness: 3.9866034984588623, equations: [-0.333, 0.939/a1, 0.124]
# Complexity: 7, fitness: 3.0999324321746826, equations: [u0 - 0.0641, 3.74, 0.18*e]
# Complexity: 11, fitness: 3.0594699382781982, equations: [0.531, 0.339 - 2.24*a1, 1.1*a1*e]
# Complexity: 13, fitness: 2.9817373752593994, equations: [-4.12*u0 - 1.02, 0.777, a0 + a1 + e + 0.364]
# Complexity: 15, fitness: 2.979081869125366, equations: [-4.12*u0 - 0.0121, -0.638*u0, a0 + a1 + e - 0.364]
# Complexity: 17, fitness: 1.7171045541763306, equations: [-1.38*a0 + u0 + y1 - 0.00483, u0, -1.55*a0 + 1.55*e - 0.374]
# In generation 4
# Complexity: 3, fitness: 3.9902639389038086, equations: [-0.806, -0.692, 0.00896]
# Complexity: 5, fitness: 3.9841954708099365, equations: [a1 + 1.08, -1.73, 0.0769]
# Complexity: 7, fitness: 3.067146062850952, equations: [a1*u0, 3.07, 0.238*e]
# Complexity: 11, fitness: 3.0594699382781982, equations: [0.531, 0.339 - 2.24*a1, 1.1*a1*e]
# Complexity: 13, fitness: 2.9817373752593994, equations: [-4.12*u0 - 1.02, 0.777, a0 + a1 + e + 0.364]
# Complexity: 15, fitness: 2.979081869125366, equations: [-4.12*u0 - 0.0121, -0.638*u0, a0 + a1 + e - 0.364]
# Complexity: 17, fitness: 1.7171045541763306, equations: [-1.38*a0 + u0 + y1 - 0.00483, u0, -1.55*a0 + 1.55*e - 0.374]
# Complexity: 19, fitness: 1.627437710762024, equations: [-2.23*a0 + u0 + y1, a0, -1.55*a0 + 1.55*e - 0.374]
# In generation 5
# Complexity: 3, fitness: 3.9879415035247803, equations: [-0.883, -3.11, 0.135]
# Complexity: 5, fitness: 3.0999324321746826, equations: [1.76, 2.12, 0.18*e]
# Complexity: 7, fitness: 3.053436517715454, equations: [0.389*a1, a0, 0.219*e]
# Complexity: 11, fitness: 2.7914655208587646, equations: [0.0577, -0.952, 0.103*a0*(2.49*e + 0.394)]
# Complexity: 15, fitness: 2.1253950595855713, equations: [-1.38*a0 + u0 - 0.275, 0.599, -a0 + e + 1.3]
# Complexity: 17, fitness: 1.7171045541763306, equations: [-1.38*a0 + u0 + y1 - 0.00483, u0, -1.55*a0 + 1.55*e - 0.374]
# Complexity: 19, fitness: 1.627437710762024, equations: [-2.23*a0 + u0 + y1, a0, -1.55*a0 + 1.55*e - 0.374]
# In generation 6
# Complexity: 3, fitness: 3.985236644744873, equations: [-0.553, a0, 0.0501]
# Complexity: 5, fitness: 3.077214002609253, equations: [a0, 2.38, 0.25*e]
# Complexity: 7, fitness: 3.053436517715454, equations: [0.389*a1, a0, 0.219*e]
# Complexity: 11, fitness: 2.7914655208587646, equations: [0.0577, -0.952, 0.103*a0*(2.49*e + 0.394)]
# Complexity: 15, fitness: 2.1253950595855713, equations: [-1.38*a0 + u0 - 0.275, 0.599, -a0 + e + 1.3]
# Complexity: 17, fitness: 1.7171045541763306, equations: [-1.38*a0 + u0 + y1 - 0.00483, u0, -1.55*a0 + 1.55*e - 0.374]
# Complexity: 19, fitness: 1.627437710762024, equations: [-2.23*a0 + u0 + y1, a0, -1.55*a0 + 1.55*e - 0.374]
# In generation 7
# Complexity: 3, fitness: 3.985236644744873, equations: [-0.553, a0, 0.0501]
# Complexity: 5, fitness: 3.067146062850952, equations: [0.0641, 2.12, 0.238*e]
# Complexity: 7, fitness: 3.053436517715454, equations: [0.389*a1, a0, 0.219*e]
# Complexity: 11, fitness: 2.7914655208587646, equations: [0.0577, -0.952, 0.103*a0*(2.49*e + 0.394)]
# Complexity: 15, fitness: 2.1253950595855713, equations: [-1.38*a0 + u0 - 0.275, 0.599, -a0 + e + 1.3]
# Complexity: 17, fitness: 1.7171045541763306, equations: [-1.38*a0 + u0 + y1 - 0.00483, u0, -1.55*a0 + 1.55*e - 0.374]
# Complexity: 19, fitness: 1.6210016012191772, equations: [-2.77*a0 + u0 + y1, a0, -1.55*a0 + 1.55*e - 0.374]
# Complexity: 23, fitness: 1.34819757938385, equations: [-0.427*a0 - a1 + u0 - 1.31*y0, a1, -a0 + 0.478*e - 0.52]
# In generation 8
# Complexity: 3, fitness: 3.985236644744873, equations: [-0.553, a0, 0.0501]
# Complexity: 5, fitness: 3.067146062850952, equations: [0.0641, 2.12, 0.238*e]
# Complexity: 7, fitness: 3.053436517715454, equations: [a0, e + 1.34, 0.219*e]
# Complexity: 11, fitness: 2.7724568843841553, equations: [0.0661, 2.32, 0.103*a0*(2.49*e + 0.394)]
# Complexity: 13, fitness: 2.239293098449707, equations: [-0.849*a0 + y1 + 1.14, a0 + 0.047, -a0 + e]
# Complexity: 15, fitness: 1.9643720388412476, equations: [-1.38*a0 + u0 - 0.00965, y0 + y1, -a0 + e - 0.934]
# Complexity: 17, fitness: 1.7171045541763306, equations: [-1.38*a0 + u0 + y1 - 0.00483, u0, -1.55*a0 + 1.55*e - 0.374]
# Complexity: 19, fitness: 1.6210016012191772, equations: [-2.77*a0 + u0 + y1, -0.374, -1.55*a0 + 1.55*e - 0.374]
# Complexity: 23, fitness: 1.34819757938385, equations: [-0.427*a0 - a1 + u0 - 1.31*y0, a1, -a0 + 0.478*e - 0.52]
# In generation 9
# Complexity: 3, fitness: 3.9844391345977783, equations: [a0, 2.38, 0.0937]
# Complexity: 5, fitness: 3.067146062850952, equations: [0.0641, 2.12, 0.238*e]
# Complexity: 7, fitness: 3.053436517715454, equations: [a0, e + 1.34, 0.219*e]
# Complexity: 11, fitness: 2.7724568843841553, equations: [0.0661, 2.32, 0.103*a0*(2.49*e + 0.394)]
# Complexity: 13, fitness: 2.239293098449707, equations: [-0.849*a0 + y1 + 1.14, a0 + 0.047, -a0 + e]
# Complexity: 15, fitness: 1.8569625616073608, equations: [-1.38*a0 + u0 + 0.256, -0.356*y1, -a0 + e + 0.242]
# Complexity: 17, fitness: 1.507615566253662, equations: [-1.38*a0 + u0 - 0.849*y0 - 1.32, u0, -a0 + e - 0.242]
# Complexity: 23, fitness: 1.34819757938385, equations: [-0.427*a0 - a1 + u0 - 1.31*y0, a1, -a0 + 0.478*e - 0.52]
# In generation 10
# Complexity: 3, fitness: 3.9844391345977783, equations: [a0, 2.38, 0.0937]
# Complexity: 5, fitness: 3.067146062850952, equations: [-0.00965, 3.11, 0.238*e]
# Complexity: 7, fitness: 3.053436517715454, equations: [a0, e + 1.34, 0.219*e]
# Complexity: 11, fitness: 2.7724568843841553, equations: [0.0661, 2.32, 0.103*a0*(2.49*e + 0.394)]
# Complexity: 13, fitness: 2.239293098449707, equations: [-0.849*a0 + y1 + 1.14, a0 + 0.047, -a0 + e]
# Complexity: 15, fitness: 1.6468265056610107, equations: [-2.77*a0 + y1 - 0.0374, 1.58, -a0 + e]
# Complexity: 17, fitness: 1.507615566253662, equations: [-1.38*a0 + u0 - 0.849*y0 - 1.32, 0.659, -a0 + e - 0.242]
# Complexity: 23, fitness: 1.34819757938385, equations: [-0.427*a0 - a1 + u0 - 1.31*y0, a1, -a0 + 0.478*e - 0.52]
# In generation 11
# Complexity: 3, fitness: 3.9844391345977783, equations: [a0, 2.38, 0.0937]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.10, 6.86, 0.219*e]
# Complexity: 11, fitness: 1.807860016822815, equations: [-0.849*a0 + y1, a0, -a0 + e - 0.242]
# Complexity: 15, fitness: 1.5882620811462402, equations: [-1.38*a0 + u0 - 0.849*y0 - 1.32, u0, -a0 + e]
# Complexity: 17, fitness: 0.6401657462120056, equations: [1.09 - 0.12*u0, e - u0 + y0, a1 + 1.14*e - 1.3]
# In generation 12
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.10, 6.86, 0.219*e]
# Complexity: 11, fitness: 1.807860016822815, equations: [-0.849*a0 + y1, a0, -a0 + e - 0.242]
# Complexity: 13, fitness: 1.6258656978607178, equations: [y0 + 1.09, -u0 + y0, a1 + 1.14*e - 1.3]
# Complexity: 15, fitness: 1.5882620811462402, equations: [-1.38*a0 + u0 - 0.849*y0 - 1.32, -0.398, -a0 + e]
# Complexity: 17, fitness: 0.6401657462120056, equations: [1.09 - 0.12*u0, e - u0 + y0, a1 + 1.14*e - 1.3]
# In generation 13
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.10, 6.86, 0.219*e]
# Complexity: 11, fitness: 1.807860016822815, equations: [-0.849*a0 + y1, a0, -a0 + e - 0.242]
# Complexity: 13, fitness: 1.6258656978607178, equations: [y0 + 1.09, -u0 + y0, a1 + 1.14*e - 1.3]
# Complexity: 15, fitness: 1.5882620811462402, equations: [-1.38*a0 + u0 - 0.849*y0 - 1.32, -0.398, -a0 + e]
# Complexity: 17, fitness: 0.6401657462120056, equations: [1.09 - 0.12*u0, e - u0 + y0, a1 + 1.14*e - 1.3]
# In generation 14
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.10, 6.86, 0.219*e]
# Complexity: 11, fitness: 1.6258656978607178, equations: [e, -u0 + y0, a1 + 1.14*e - 1.3]
# Complexity: 15, fitness: 1.2771391868591309, equations: [1.09, e - 1.88*u0 + y0, a1 + 1.14*e - 1.3]
# Complexity: 17, fitness: 0.6401657462120056, equations: [1.09 - 0.12*u0, e - u0 + y0, a1 + 1.14*e - 1.3]
# In generation 15
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.10, 6.86, 0.219*e]
# Complexity: 11, fitness: 1.6258656978607178, equations: [1.11, -u0 + y0, a1 + 1.14*e - 1.3]
# Complexity: 15, fitness: 0.6401657462120056, equations: [-0.12*u0, e - u0 + y0, a1 + 1.14*e - 1.3]
# In generation 16
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.10, 6.86, 0.219*e]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.133, -u0 + y0, a1 + 1.14*e]
# Complexity: 13, fitness: 0.6401657462120056, equations: [-0.120, e - u0 + y0, a1 + 1.14*e - 1.3]
# In generation 17
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.10, 6.86, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.133, -u0 + y0, a1 + 1.14*e]
# Complexity: 13, fitness: 0.6401657462120056, equations: [-0.120, e - u0 + y0, a1 + 1.14*e - 1.3]
# In generation 18
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.10, 6.86, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.133, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 1.4217984676361084, equations: [1.11, -u0 + y0, a1 + 1.14*e - 0.0678]
# Complexity: 13, fitness: 0.6401657462120056, equations: [-0.120, e - u0 + y0, a1 + 1.14*e - 1.3]
# Complexity: 17, fitness: 0.5770261883735657, equations: [0.0549, e - u0 + y0, 2.14*a1 + 1.3*e - 1.49]
# In generation 19
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.10, 6.86, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 1.4217984676361084, equations: [1.11, -u0 + y0, a1 + 1.14*e - 0.0678]
# Complexity: 13, fitness: 0.6401657462120056, equations: [-0.120, e - u0 + y0, a1 + 1.14*e - 1.3]
# Complexity: 17, fitness: 0.4161915183067322, equations: [1.21, e - 2*u0 + 2*y0, a1 + 1.14*e - 1.3]
# In generation 20
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 1.4217984676361084, equations: [1.11, -u0 + y0, a1 + 1.14*e - 0.0678]
# Complexity: 13, fitness: 0.6401657462120056, equations: [-1.20, e - u0 + y0, a1 + 1.14*e - 1.3]
# Complexity: 17, fitness: 0.4161915183067322, equations: [1.21, e - 2*u0 + 2*y0, a1 + 1.14*e - 1.3]
# In generation 21
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 1.4217984676361084, equations: [1.11, -u0 + y0, a1 + 1.14*e - 0.0678]
# Complexity: 13, fitness: 0.6401657462120056, equations: [-1.20, e - u0 + y0, a1 + 1.14*e - 1.3]
# Complexity: 17, fitness: 0.4161915183067322, equations: [1.21, e - 2*u0 + 2*y0, a1 + 1.14*e - 1.3]
# In generation 22
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 1.4217984676361084, equations: [1.11, -u0 + y0, a1 + 1.14*e - 0.0678]
# Complexity: 13, fitness: 0.6401657462120056, equations: [-1.20, e - u0 + y0, a1 + 1.14*e - 1.3]
# Complexity: 17, fitness: 0.4161915183067322, equations: [1.21, e - 2*u0 + 2*y0, a1 + 1.14*e - 1.3]
# In generation 23
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 1.4217984676361084, equations: [1.11, -u0 + y0, a1 + 1.14*e - 0.0678]
# Complexity: 13, fitness: 0.6401657462120056, equations: [-1.20, e - u0 + y0, a1 + 1.14*e - 1.3]
# Complexity: 17, fitness: 0.4161915183067322, equations: [1.21, e - 2*u0 + 2*y0, a1 + 1.14*e - 1.3]
# Complexity: 21, fitness: 0.41032475233078003, equations: [2.19 - u0**2, e - 2*u0 + 2*y0, a1 + 1.14*e]
# In generation 24
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 1.4217984676361084, equations: [1.11, -u0 + y0, a1 + 1.14*e - 0.0678]
# Complexity: 13, fitness: 0.6401657462120056, equations: [-1.20, e - u0 + y0, a1 + 1.14*e - 1.3]
# Complexity: 17, fitness: 0.4161915183067322, equations: [1.21, e - 2*u0 + 2*y0, a1 + 1.14*e - 1.3]
# Complexity: 21, fitness: 0.41032475233078003, equations: [2.19 - u0**2, e - 2*u0 + 2*y0, a1 + 1.14*e]
# In generation 25
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 1.4217984676361084, equations: [1.11, -u0 + y0, a1 + 1.14*e - 0.0678]
# Complexity: 13, fitness: 0.6401657462120056, equations: [-1.20, e - u0 + y0, a1 + 1.14*e - 1.3]
# Complexity: 17, fitness: 0.36011797189712524, equations: [-1.20, e - 2*u0 + 2*y0, a1 + 0.947*e - 1.08]
# In generation 26
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 1.4217984676361084, equations: [1.11, -u0 + y0, a1 + 1.14*e - 0.0678]
# Complexity: 13, fitness: 0.6401657462120056, equations: [-1.20, e - u0 + y0, a1 + 1.14*e - 1.3]
# Complexity: 15, fitness: 0.5150534510612488, equations: [2.29, e - 2*u0 + 2*y0, a1 + 1.42*e]
# Complexity: 17, fitness: 0.36011797189712524, equations: [-1.20, e - 2*u0 + 2*y0, a1 + 0.947*e - 1.08]
# In generation 27
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 1.4217984676361084, equations: [1.11, -u0 + y0, a1 + 1.14*e - 0.0678]
# Complexity: 13, fitness: 0.6401657462120056, equations: [-1.20, e - u0 + y0, a1 + 1.14*e - 1.3]
# Complexity: 15, fitness: 0.41032475233078003, equations: [a0, e - 2*u0 + 2*y0, a1 + 1.14*e]
# Complexity: 17, fitness: 0.36011797189712524, equations: [-1.20, e - 2*u0 + 2*y0, a1 + 0.947*e - 1.08]
# In generation 28
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 1.4217984676361084, equations: [1.11, -u0 + y0, a1 + 1.14*e - 0.0678]
# Complexity: 13, fitness: 0.6401657462120056, equations: [-1.20, e - u0 + y0, a1 + 1.14*e - 1.3]
# Complexity: 15, fitness: 0.41032475233078003, equations: [a0, e - 2*u0 + 2*y0, a1 + 1.14*e]
# Complexity: 17, fitness: 0.36011797189712524, equations: [-1.20, e - 2*u0 + 2*y0, a1 + 0.947*e - 1.08]
# In generation 29
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6553770303726196, equations: [u0, e - u0 + y0, a1 + 1.14*e]
# Complexity: 13, fitness: 0.6401657462120056, equations: [-1.20, e - u0 + y0, a1 + 1.14*e - 1.3]
# Complexity: 15, fitness: 0.41032475233078003, equations: [a0, e - 2*u0 + 2*y0, a1 + 1.14*e]
# Complexity: 17, fitness: 0.36011797189712524, equations: [-1.20, e - 2*u0 + 2*y0, a1 + 0.947*e - 1.08]
# In generation 30
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6553770303726196, equations: [1.81, e - u0 + y0, a1 + 1.14*e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [0.805, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [u0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.30369487404823303, equations: [-0.0729, e - 2*u0 + 2*y0, a1 + 0.589*e]
# In generation 31
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6553770303726196, equations: [1.81, e - u0 + y0, a1 + 1.14*e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [0.805, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [u0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.30369487404823303, equations: [-0.0729, e - 2*u0 + 2*y0, a1 + 0.589*e]
# In generation 32
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6553770303726196, equations: [1.81, e - u0 + y0, a1 + 1.14*e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [0.805, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [u0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.30369487404823303, equations: [-0.0729, e - 2*u0 + 2*y0, a1 + 0.589*e]
# In generation 33
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6553770303726196, equations: [1.81, e - u0 + y0, a1 + 1.14*e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [0.805, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [u0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.30369487404823303, equations: [-0.0729, e - 2*u0 + 2*y0, a1 + 0.589*e]
# In generation 34
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6553770303726196, equations: [1.81, e - u0 + y0, a1 + 1.14*e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [0.805, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [u0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.30369487404823303, equations: [-0.0729, e - 2*u0 + 2*y0, a1 + 0.589*e]
# Complexity: 31, fitness: 0.2875998020172119, equations: [u0*(-u0**2 - 1.31*y0 + 1.09), e - 2*u0 + 2*y0, 0.516*a1 + 0.589*e]
# In generation 35
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6553770303726196, equations: [1.81, e - u0 + y0, a1 + 1.14*e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [0.805, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [a0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.30369487404823303, equations: [-1.12, e - 2*u0 + 2*y0, a1 + 0.589*e]
# Complexity: 23, fitness: 0.2834753096103668, equations: [-0.0729, e - 2*u0 + 2*y0, 0.516*a1 + 0.589*e - 0.304]
# In generation 36
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6553770303726196, equations: [1.81, e - u0 + y0, a1 + 1.14*e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [0.805, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [a0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.30369487404823303, equations: [-1.12, e - 2*u0 + 2*y0, a1 + 0.589*e]
# Complexity: 21, fitness: 0.2834753096103668, equations: [-1.31*y0, e - 2*u0 + 2*y0, 0.516*a1 + 0.589*e - 0.304]
# In generation 37
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6553770303726196, equations: [1.81, e - u0 + y0, a1 + 1.14*e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [-2.55, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [a0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.30369487404823303, equations: [-1.12, e - 2*u0 + 2*y0, a1 + 0.589*e]
# Complexity: 21, fitness: 0.2834753096103668, equations: [-1.31*y0, e - 2*u0 + 2*y0, 0.516*a1 + 0.589*e - 0.304]
# In generation 38
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6553770303726196, equations: [1.81, e - u0 + y0, a1 + 1.14*e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [-2.55, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [a0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.30369487404823303, equations: [-1.12, e - 2*u0 + 2*y0, a1 + 0.589*e]
# Complexity: 21, fitness: 0.2834753096103668, equations: [-1.31*y0, e - 2*u0 + 2*y0, 0.516*a1 + 0.589*e - 0.304]
# In generation 39
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6202225685119629, equations: [a0*u0, e - u0 + y0, a1 + e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [-2.55, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [a0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.30369487404823303, equations: [-1.12, e - 2*u0 + 2*y0, a1 + 0.589*e]
# Complexity: 21, fitness: 0.2834753096103668, equations: [-1.31*y0, e - 2*u0 + 2*y0, 0.516*a1 + 0.589*e - 0.304]
# Complexity: 35, fitness: 0.26960647106170654, equations: [-1.19*a0 + u0 + y1, e - 2*u0 + 2*y0, -2*a0 + a1 + 0.516*e - 1.36]
# In generation 40
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6202225685119629, equations: [a0*u0, e - u0 + y0, a1 + e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [-2.55, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [a0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.30369487404823303, equations: [-1.12, e - 2*u0 + 2*y0, a1 + 0.589*e]
# Complexity: 19, fitness: 0.2834753096103668, equations: [u0, e - 2*u0 + 2*y0, 0.516*a1 + 0.589*e - 0.304]
# Complexity: 21, fitness: 0.2582237124443054, equations: [e + u0, e - 2*u0 + 2*y0 - y1, a1 + 0.85]
# In generation 41
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6202225685119629, equations: [a0*u0, e - u0 + y0, a1 + e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [-2.55, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [a0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.30369487404823303, equations: [-1.12, e - 2*u0 + 2*y0, a1 + 0.589*e]
# Complexity: 19, fitness: 0.2582237124443054, equations: [u0, e - 2*u0 + 2*y0 - y1, a1 + 0.85]
# In generation 42
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6202225685119629, equations: [a0*u0, e - u0 + y0, a1 + e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [-2.55, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [a0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.30369487404823303, equations: [-1.12, e - 2*u0 + 2*y0, a1 + 0.589*e]
# Complexity: 19, fitness: 0.2582237124443054, equations: [u0, e - 2*u0 + 2*y0 - y1, a1 + 0.85]
# In generation 43
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6202225685119629, equations: [a0*u0, e - u0 + y0, a1 + e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [-2.55, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [a0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.30369487404823303, equations: [-1.12, e - 2*u0 + 2*y0, a1 + 0.589*e]
# Complexity: 19, fitness: 0.2582237124443054, equations: [u0, e - 2*u0 + 2*y0 - y1, a1 + 0.85]
# Complexity: 25, fitness: 0.24218395352363586, equations: [-e + u0**2, e - 2*u0 + 2*y0 - y1, a1]
# In generation 44
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6202225685119629, equations: [a0*u0, e - u0 + y0, a1 + e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [-2.55, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [a0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.30369487404823303, equations: [-1.12, e - 2*u0 + 2*y0, a1 + 0.589*e]
# Complexity: 19, fitness: 0.2582237124443054, equations: [u0, e - 2*u0 + 2*y0 - y1, a1 + 0.85]
# Complexity: 21, fitness: 0.24378299713134766, equations: [e + u0, e - 2*u0 + 2*y0 - y1, a1 - 0.805]
# Complexity: 25, fitness: 0.24218395352363586, equations: [u0**2 - 1.01*u0, e - 2*u0 + 2*y0 - y1, a1]
# In generation 45
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6202225685119629, equations: [a0*u0, e - u0 + y0, a1 + e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [-2.55, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [a0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.30369487404823303, equations: [-1.12, e - 2*u0 + 2*y0, a1 + 0.589*e]
# Complexity: 19, fitness: 0.24218395352363586, equations: [e + 2.01, e - 2*u0 + 2*y0 - y1, a1]
# In generation 46
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6202225685119629, equations: [a0*u0, e - u0 + y0, a1 + e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [-2.55, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [a0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.30369487404823303, equations: [-1.12, e - 2*u0 + 2*y0, a1 + 0.589*e]
# Complexity: 19, fitness: 0.24218395352363586, equations: [e + 2.01, e - 2*u0 + 2*y0 - y1, a1]
# In generation 47
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6202225685119629, equations: [a0*u0, e - u0 + y0, a1 + e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [-2.55, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [a0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.24218395352363586, equations: [-0.134, e - 2*u0 + 2*y0 - y1, a1]
# In generation 48
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6202225685119629, equations: [a0*u0, e - u0 + y0, a1 + e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [-2.55, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [a0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.24218395352363586, equations: [-1.31, e - 2*u0 + 2*y0 - y1, a1]
# In generation 49
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6202225685119629, equations: [a0*u0, e - u0 + y0, a1 + e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [-2.55, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [a0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.24218395352363586, equations: [-1.31, e - 2*u0 + 2*y0 - y1, a1]
# In generation 50
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6202225685119629, equations: [a0*u0, e - u0 + y0, a1 + e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [-2.55, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [a0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.24218395352363586, equations: [-1.54, e - 2*u0 + 2*y0 - y1, a1]
# Final pareto front:
# Complexity: 3, fitness: 3.984196186065674, equations: [y0, -2.28, 0.0769]
# Complexity: 5, fitness: 3.053436517715454, equations: [-1.31, e, 0.219*e]
# Complexity: 7, fitness: 2.967637777328491, equations: [-0.133, -2*u0 + y0, a1]
# Complexity: 9, fitness: 1.4286067485809326, equations: [-0.739, -u0 + y0, a1 + 1.14*e]
# Complexity: 11, fitness: 0.6202225685119629, equations: [a0*u0, e - u0 + y0, a1 + e]
# Complexity: 13, fitness: 0.5935859084129333, equations: [-2.55, e - u0 + y0, a1 + 0.947*e - 1.08]
# Complexity: 15, fitness: 0.3557892143726349, equations: [a0, e - 2*u0 + 2*y0, a1 + 0.947*e]
# Complexity: 17, fitness: 0.24218395352363586, equations: [-1.54, e - 2*u0 + 2*y0 - y1, a1]

# %%
# Get the best solution from the pareto front
best_idx = jnp.argmin(jnp.array(strategy.pareto_front[0]))
best_fitness = strategy.pareto_front[0][best_idx]  # Best fitness
best_solution = strategy.pareto_front[1][best_idx]  # Best solution
best_solution_str = strategy.expression_to_string(best_solution)

print(f"Final best fitness: {best_fitness}")
print(f"Final best solution: {best_solution_str}")

os.makedirs(save_path, exist_ok=True)
np.save(f'{save_path}/best_fitnesses.npy', best_fitnesses)
np.save(f'{save_path}/best_solutions.npy', strategy.pareto_front[1])
# Out:
# Final best fitness: 0.24218395352363586
# Final best solution: [-1.54, e - 2*u0 + 2*y0 - y1, a1]

# %%
env = HarmonicOscillator(process_noise=args["process_noise"], obs_noise=args["obs_noise"])
test_data = get_data(jr.PRNGKey(10), env, 4, 0.2, 40.0, args["param_setting"], n_jumps=3)
x0s, ts, targets, noise_key, params = test_data
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.3),
    ("/", lambda x, y: jnp.divide(x, y), 2, 0.1)
]
strategy, fitness_function = get_strategy(env, operator_list, 0.05, feedback_fn=distance_feedback, device=device)
best_fitness, best_model = validate(np.load(f'{save_path}/best_solutions.npy'), strategy, test_data)
print(f"Best fitness on test data: {best_fitness}")
# Out:
# Input data should be formatted as: ['y0', 'y1', 'a0', 'a1', 'u0', 'e'].
# Best fitness on test data: 0.6002932786941528

# %%
xs, ys, us, activities, fitness, fbs = jax.vmap(fitness_function.evaluate_trajectory, in_axes=[
    None, 0, None, 0, 0, 0, None])(best_model, *test_data, strategy.tree_evaluator)

fig, ax = plt.subplots(2, 2, figsize=(9.5, 5))
ax = ax.ravel()
for i in range(4):
    ax[i].plot(ts, xs[i, :, 0], label="$x_0$", color="#1f77b4", linewidth=1.8)
    ax[i].plot(ts, xs[i, :, 1], label="$x_1$", color="#ff7f0e", linewidth=1.8)
    ax[i].plot(ts, ys[i, :, 0], alpha=0.2, color="#1f77b4")
    ax[i].plot(ts, ys[i, :, 1], alpha=0.2, color="#ff7f0e")
    ax[i].plot(ts, us[i, :], label="$u$", color="#2ca02c", linewidth=1.5)
    ax[i].plot(ts, fbs[i, :], label="$r$", color="#d62728", linewidth=1.2)
    ax[i].plot(ts, targets[i, :, 0], '--k', lw=2)
    ax[i].set_xlabel("Time")
    ax[i].legend(loc="upper right", fontsize=9, frameon=False, ncols=2)
    ax[i].spines[['right', 'top']].set_visible(False)
    ax[i].autoscale_view(scalex=True, scaley=True)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
