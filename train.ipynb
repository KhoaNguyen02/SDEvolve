# %%
import os
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count=10'

import jax
import jax.random as jr
import jax.numpy as jnp
from utils import *
from main import run_experiment
from environments.harmonic_oscillator import HarmonicOscillator
import numpy as np
import matplotlib.pyplot as plt

device = jax.devices()[0].platform
print(f"Using device: {device}")
# Out:
# These device(s) are detected:  [CpuDevice(id=0), CpuDevice(id=1), CpuDevice(id=2), CpuDevice(id=3), CpuDevice(id=4), CpuDevice(id=5), CpuDevice(id=6), CpuDevice(id=7), CpuDevice(id=8), CpuDevice(id=9)]
# Using device: cpu

# %%
def distance_feedback(x, target):
    return 0.5 * (target - x[0])**2

def direction_feedback(x, target):
    return target - x[0]

args = {
    "param_setting": "constant",
    "batch_size": 16,
    "n_obs": 2,
    "process_noise": 0.05,
    "obs_noise": 0.3,
    "num_generations": 50,
    "population_size": 100,
    "num_populations": 10
}

save_path = 'results/harmonic_oscillator/full_obs/gp-ode/noisy_obs'
os.makedirs(save_path, exist_ok=True)

learn_condition = 3
feedback_fn = None
sign_estimation = False

# %%
strategy, best_fitnesses = run_experiment(args, learn_condition, feedback_fn, sign_estimation, save_path=save_path, device=device)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'a0', 'a1', 'u0'].
# Compiling code for evaluation and evolution...
# Finished compilation in 45.73 seconds
# In generation 1
# Complexity: 5, fitness: 1.7022171020507812, equations: [0.379, -0.332*a1, 0.594]
# Complexity: 7, fitness: 1.3203585147857666, equations: [-0.644, -2.48, 0]
# Complexity: 13, fitness: 1.315101981163025, equations: [-0.978*y1, -0.217*a0 + 0.217*y0, a0 - 0.217]
# Complexity: 17, fitness: 1.2541474103927612, equations: [-0.42*a0 + y1 - 0.00395, -0.507, a0**2*(a0*a1 + 1.52)]
# Complexity: 19, fitness: 1.2382733821868896, equations: [u0 + 0.425*y1, u0**2*y0 + 0.134, 1.48 - 1.97*a0]
# In generation 2
# Complexity: 3, fitness: 4.036589622497559, equations: [-5.58, 0.0284, 1.52]
# Complexity: 5, fitness: 1.3188995122909546, equations: [y1 + 0.0686, 0.880, 0.0328]
# Complexity: 13, fitness: 1.2320650815963745, equations: [a0*(1.09 - u0), -1.23*u0 - 1.23*y1, a1 - 0.135]
# In generation 3
# Complexity: 3, fitness: 1.3189834356307983, equations: [y0, -2.65, 0.0430]
# Complexity: 5, fitness: 1.3188995122909546, equations: [y1 - 0.229, -0.308, 0.0328]
# Complexity: 7, fitness: 1.231025218963623, equations: [y1, -1.23*u0 - 1.23*y1, a1]
# Complexity: 21, fitness: 1.2301321029663086, equations: [0.796*a1**2*u0, -0.42*a0*y1 + u0 + y1, -1.82*a0 - 1.82*a1]
# In generation 4
# Complexity: 3, fitness: 1.3189834356307983, equations: [-0.179, -2.65, 0.0430]
# Complexity: 5, fitness: 1.3188995122909546, equations: [y1 - 0.229, -0.308, 0.0328]
# Complexity: 7, fitness: 1.231025218963623, equations: [y1, -1.23*u0 - 1.23*y1, a1]
# Complexity: 19, fitness: 1.2300716638565063, equations: [0.796*u0*y0, -0.42*a0*y1 + u0 + y1, -1.82*a0 - 1.82*a1]
# In generation 5
# Complexity: 3, fitness: 1.3189834356307983, equations: [-0.179, -2.65, 0.0430]
# Complexity: 5, fitness: 1.3188995122909546, equations: [y1 - 0.229, -0.308, 0.0328]
# Complexity: 7, fitness: 1.2307919263839722, equations: [u0 + y1, y1, -1.33*a0]
# Complexity: 19, fitness: 1.2300716638565063, equations: [0.796*u0*y0, -0.42*a0*y1 + u0 + y1, -1.82*a0 - 1.82*a1]
# In generation 6
# Complexity: 3, fitness: 1.3189834356307983, equations: [-0.179, -2.65, 0.0430]
# Complexity: 5, fitness: 1.3188995122909546, equations: [y1 - 0.229, -0.308, 0.0328]
# Complexity: 7, fitness: 1.2307919263839722, equations: [u0 + y1, y1, -1.33*a0]
# Complexity: 11, fitness: 1.2301098108291626, equations: [2.27*u0 + 3.36*y1, -0.0386, -0.847*a0]
# Complexity: 19, fitness: 1.2300716638565063, equations: [0.796*u0*y0, -0.42*a0*y1 + u0 + y1, -1.82*a0 - 1.82*a1]
# Complexity: 21, fitness: 1.229974627494812, equations: [0.796*u0*y0, 1.4*a0*a1*y1 + u0 + y1, -1.82*a0 - 1.82*a1]
# Complexity: 29, fitness: 1.2294918298721313, equations: [u0 + y0*(0.939*u0 + 0.399*y1) + y1, -0.956/(-a1 + u0 + 2.18), -2.92*a0]
# In generation 7
# Complexity: 3, fitness: 1.3189834356307983, equations: [-0.179, -2.65, 0.0430]
# Complexity: 5, fitness: 1.3188995122909546, equations: [y1 - 0.229, -0.308, 0.0328]
# Complexity: 7, fitness: 1.2307919263839722, equations: [u0 + y1, y1, -1.33*a0]
# Complexity: 11, fitness: 1.2301098108291626, equations: [2.27*u0 + 3.36*y1, -0.0386, -0.847*a0]
# Complexity: 19, fitness: 1.2300716638565063, equations: [0.796*u0*y0, -0.42*a0*y1 + u0 + y1, -1.82*a0 - 1.82*a1]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 8
# Complexity: 3, fitness: 1.3188995122909546, equations: [u0, 0.135, 0.0328]
# Complexity: 7, fitness: 1.2307919263839722, equations: [u0 + y1, y1, -1.33*a0]
# Complexity: 11, fitness: 1.2301098108291626, equations: [2.27*u0 + 3.36*y1, -2.08, -0.847*a0]
# Complexity: 15, fitness: 1.229918122291565, equations: [0.796*u0*y0, u0 + y1, -2.13*a1]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 9
# Complexity: 3, fitness: 1.3188995122909546, equations: [u0, 0.135, 0.0328]
# Complexity: 7, fitness: 1.2307919263839722, equations: [u0 + y1, y1, -1.33*a0]
# Complexity: 9, fitness: 1.229777216911316, equations: [-1.67, -1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 10
# Complexity: 3, fitness: 1.3188995122909546, equations: [0.312, -0.970, 0.0328]
# Complexity: 7, fitness: 1.2307919263839722, equations: [u0 + y1, y1, -1.33*a0]
# Complexity: 9, fitness: 1.229777216911316, equations: [-1.67, -1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 11
# Complexity: 3, fitness: 1.3188995122909546, equations: [0.312, -0.970, 0.0328]
# Complexity: 7, fitness: 1.2307919263839722, equations: [u0 + y1, y1, -1.33*a0]
# Complexity: 9, fitness: 1.229777216911316, equations: [-1.67, -1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 13, fitness: 1.2296252250671387, equations: [3.0*u0 + 4.45*y1, -0.0165, -2.69*a0]
# Complexity: 19, fitness: 1.2295516729354858, equations: [a0**2*y1, -3.7*u0 - 3.7*y1, a1]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 12
# Complexity: 3, fitness: 1.3188995122909546, equations: [-0.755, a1, 0.0328]
# Complexity: 7, fitness: 1.2307919263839722, equations: [u0 + y1, y1, -1.33*a0]
# Complexity: 9, fitness: 1.229777216911316, equations: [-1.67, -1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 13, fitness: 1.2296252250671387, equations: [3.0*u0 + 4.45*y1, -0.155, -2.69*a0]
# Complexity: 15, fitness: 1.2294267416000366, equations: [7.42*u0 + 7.62*y1, u0, -0.847*a0]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 13
# Complexity: 3, fitness: 1.3188995122909546, equations: [-0.755, a1, 0.0328]
# Complexity: 7, fitness: 1.2307919263839722, equations: [u0 + y1, y1, -1.33*a0]
# Complexity: 9, fitness: 1.229777216911316, equations: [-1.67, -1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 13, fitness: 1.2296252250671387, equations: [3.0*u0 + 4.45*y1, -0.155, -2.69*a0]
# Complexity: 15, fitness: 1.2294267416000366, equations: [7.42*u0 + 7.62*y1, a0, -0.847*a0]
# Complexity: 17, fitness: 1.229321002960205, equations: [3.79, -1.23*u0 - 1.23*y1, -2.73*(a1 - 1.06)*(a1 - 0.135) + 0.827]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 14
# Complexity: 3, fitness: 1.3188995122909546, equations: [-0.755, a1, 0.0328]
# Complexity: 7, fitness: 1.2307919263839722, equations: [u0 + y1, y1, -1.33*a0]
# Complexity: 9, fitness: 1.229777216911316, equations: [-1.67, -1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 13, fitness: 1.2296252250671387, equations: [3.0*u0 + 4.45*y1, -0.155, -2.69*a0]
# Complexity: 15, fitness: 1.2294267416000366, equations: [7.42*u0 + 7.62*y1, a0, -0.847*a0]
# Complexity: 17, fitness: 1.229321002960205, equations: [3.79, -1.23*u0 - 1.23*y1, -2.73*(a1 - 1.06)*(a1 - 0.135) + 0.827]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 15
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.2307919263839722, equations: [u0 + y1, y1, -1.33*a0]
# Complexity: 9, fitness: 1.229777216911316, equations: [-1.67, -1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 13, fitness: 1.2296252250671387, equations: [3.0*u0 + 4.45*y1, -0.155, -2.69*a0]
# Complexity: 15, fitness: 1.2294267416000366, equations: [7.42*u0 + 7.62*y1, a0, -0.847*a0]
# Complexity: 17, fitness: 1.229321002960205, equations: [3.79, -1.23*u0 - 1.23*y1, -2.73*(a1 - 1.06)*(a1 - 0.135) + 0.827]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 16
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.2307919263839722, equations: [u0 + y1, y1, -1.33*a0]
# Complexity: 9, fitness: 1.229777216911316, equations: [-1.67, -1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 11, fitness: 1.2297676801681519, equations: [1.32*u0 + 1.96*y1, 2.93, -2.69*a0]
# Complexity: 13, fitness: 1.2296252250671387, equations: [3.0*u0 + 4.45*y1, -0.155, -2.69*a0]
# Complexity: 15, fitness: 1.2294267416000366, equations: [7.42*u0 + 7.62*y1, 1.51, -0.847*a0]
# Complexity: 17, fitness: 1.229321002960205, equations: [3.79, -1.23*u0 - 1.23*y1, -2.73*(a1 - 1.06)*(a1 - 0.135) + 0.827]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 17
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.2307919263839722, equations: [u0 + y1, y1, -1.33*a0]
# Complexity: 9, fitness: 1.229777216911316, equations: [-1.67, -1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 11, fitness: 1.2297676801681519, equations: [1.32*u0 + 1.96*y1, 2.93, -2.69*a0]
# Complexity: 13, fitness: 1.2296252250671387, equations: [3.0*u0 + 4.45*y1, -0.155, -2.69*a0]
# Complexity: 15, fitness: 1.2287874221801758, equations: [y1, -1.23*a0 - 3.7*u0 - 2.46*y1, a1]
# Complexity: 19, fitness: 1.2285250425338745, equations: [4.54*u0 + 3.36*y1, y0 - 0.155, -a0 - a1 + 0.523]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 18
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.2307919263839722, equations: [u0 + y1, y1, -1.33*a0]
# Complexity: 9, fitness: 1.229777216911316, equations: [-1.67, -1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 11, fitness: 1.2297676801681519, equations: [1.32*u0 + 1.96*y1, 2.93, -2.69*a0]
# Complexity: 13, fitness: 1.2296252250671387, equations: [3.0*u0 + 4.45*y1, -0.155, -2.69*a0]
# Complexity: 15, fitness: 1.2287874221801758, equations: [y1, -1.23*a0 - 3.7*u0 - 2.46*y1, a1]
# Complexity: 19, fitness: 1.2282850742340088, equations: [y1 + 0.125, -3.7*u0 - 1.23*y0 - 3.7*y1, a1]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 19
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.2307919263839722, equations: [u0 + y1, y1, -1.33*a0]
# Complexity: 9, fitness: 1.229777216911316, equations: [-1.67, -1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 11, fitness: 1.2297676801681519, equations: [1.32*u0 + 1.96*y1, 2.93, -2.69*a0]
# Complexity: 13, fitness: 1.2296252250671387, equations: [3.0*u0 + 4.45*y1, -0.155, -2.69*a0]
# Complexity: 15, fitness: 1.2287874221801758, equations: [y1, -1.23*a0 - 3.7*u0 - 2.46*y1, a1]
# Complexity: 19, fitness: 1.227901816368103, equations: [-0.155, -3.7*u0 - 1.23*y0 - 3.7*y1, 2*a1]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 20
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.2307919263839722, equations: [u0 + y1, y1, -1.33*a0]
# Complexity: 9, fitness: 1.229777216911316, equations: [-1.67, -1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 11, fitness: 1.2297676801681519, equations: [1.32*u0 + 1.96*y1, 2.93, -2.69*a0]
# Complexity: 13, fitness: 1.2296252250671387, equations: [3.0*u0 + 4.45*y1, -0.155, -2.69*a0]
# Complexity: 15, fitness: 1.2287874221801758, equations: [y1, -1.23*a0 - 3.7*u0 - 2.46*y1, a1]
# Complexity: 17, fitness: 1.2282850742340088, equations: [-0.155, -3.7*u0 - 1.23*y0 - 3.7*y1, a1]
# Complexity: 19, fitness: 1.227901816368103, equations: [-0.155, -3.7*u0 - 1.23*y0 - 3.7*y1, 2*a1]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 21
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.2307919263839722, equations: [u0 + y1, y1, -1.33*a0]
# Complexity: 9, fitness: 1.229777216911316, equations: [-1.67, -1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 11, fitness: 1.2297676801681519, equations: [1.32*u0 + 1.96*y1, 2.93, -2.69*a0]
# Complexity: 13, fitness: 1.2296252250671387, equations: [3.0*u0 + 4.45*y1, -0.155, -2.69*a0]
# Complexity: 15, fitness: 1.2287874221801758, equations: [y1, -1.23*a0 - 3.7*u0 - 2.46*y1, a1]
# Complexity: 17, fitness: 1.2282850742340088, equations: [-0.155, -3.7*u0 - 1.23*y0 - 3.7*y1, a1]
# Complexity: 19, fitness: 1.227901816368103, equations: [-0.155, -3.7*u0 - 1.23*y0 - 3.7*y1, 2*a1]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 22
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.2307919263839722, equations: [u0 + y1, y1, -1.33*a0]
# Complexity: 9, fitness: 1.229777216911316, equations: [-1.67, -1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 11, fitness: 1.2297676801681519, equations: [1.32*u0 + 1.96*y1, 2.93, -2.69*a0]
# Complexity: 13, fitness: 1.2296252250671387, equations: [3.0*u0 + 4.45*y1, -0.155, -2.69*a0]
# Complexity: 15, fitness: 1.2287874221801758, equations: [y1, -1.23*a0 - 3.7*u0 - 2.46*y1, a1]
# Complexity: 17, fitness: 1.2282850742340088, equations: [-0.155, -3.7*u0 - 1.23*y0 - 3.7*y1, a1]
# Complexity: 19, fitness: 1.2277923822402954, equations: [1.9*u0, -2.46*u0 - 1.23*y0 - 2.46*y1, 2*a1]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 23
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.2307919263839722, equations: [u0 + y1, y1, -1.33*a0]
# Complexity: 9, fitness: 1.229777216911316, equations: [-1.67, -1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 11, fitness: 1.2297676801681519, equations: [1.32*u0 + 1.96*y1, 2.93, -2.69*a0]
# Complexity: 13, fitness: 1.2296252250671387, equations: [3.0*u0 + 4.45*y1, -0.155, -2.69*a0]
# Complexity: 15, fitness: 1.2287874221801758, equations: [y1, -1.23*a0 - 3.7*u0 - 2.46*y1, a1]
# Complexity: 17, fitness: 1.228170394897461, equations: [0.796, -2.46*u0 - 1.23*y0 - 3.7*y1, 2*a1]
# Complexity: 19, fitness: 1.2277923822402954, equations: [1.9*u0, -2.46*u0 - 1.23*y0 - 2.46*y1, 2*a1]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 24
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.2307919263839722, equations: [u0 + y1, y1, -1.33*a0]
# Complexity: 9, fitness: 1.229777216911316, equations: [-1.67, -1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 11, fitness: 1.2297676801681519, equations: [1.32*u0 + 1.96*y1, 2.93, -2.69*a0]
# Complexity: 13, fitness: 1.2296252250671387, equations: [3.0*u0 + 4.45*y1, -0.155, -2.69*a0]
# Complexity: 15, fitness: 1.2287874221801758, equations: [y1, -1.23*a0 - 3.7*u0 - 2.46*y1, a1]
# Complexity: 17, fitness: 1.228170394897461, equations: [0.796, -2.46*u0 - 1.23*y0 - 3.7*y1, 2*a1]
# Complexity: 19, fitness: 1.2277923822402954, equations: [1.9*u0, -2.46*u0 - 1.23*y0 - 2.46*y1, 2*a1]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 25
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 13, fitness: 1.2292629480361938, equations: [u0, u0 + y1, 0.369 - 2.73*a1]
# Complexity: 15, fitness: 1.2287874221801758, equations: [y1, -1.23*a0 - 3.7*u0 - 2.46*y1, a1]
# Complexity: 17, fitness: 1.228170394897461, equations: [-0.135, -2.46*u0 - 1.23*y0 - 3.7*y1, 2*a1]
# Complexity: 19, fitness: 1.2277923822402954, equations: [1.9*u0, -2.46*u0 - 1.23*y0 - 2.46*y1, 2*a1]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 26
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 13, fitness: 1.2292629480361938, equations: [u0, u0 + y1, 0.369 - 2.73*a1]
# Complexity: 15, fitness: 1.2287874221801758, equations: [y1, -1.23*a0 - 3.7*u0 - 2.46*y1, a1]
# Complexity: 17, fitness: 1.228170394897461, equations: [-0.135, -2.46*u0 - 1.23*y0 - 3.7*y1, 2*a1]
# Complexity: 19, fitness: 1.2277923822402954, equations: [1.9*u0, -2.46*u0 - 1.23*y0 - 2.46*y1, 2*a1]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 27
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 13, fitness: 1.2292629480361938, equations: [u0, u0 + y1, 0.369 - 2.73*a1]
# Complexity: 15, fitness: 1.2287874221801758, equations: [y1, -1.23*a0 - 3.7*u0 - 2.46*y1, a1]
# Complexity: 17, fitness: 1.228170394897461, equations: [-0.135, -2.46*u0 - 1.23*y0 - 3.7*y1, 2*a1]
# Complexity: 19, fitness: 1.2277923822402954, equations: [1.9*u0, -2.46*u0 - 1.23*y0 - 2.46*y1, 2*a1]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 28
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 13, fitness: 1.228823184967041, equations: [u0, -2.46*u0 - 1.23*y0 - 2.46*y1, a1]
# Complexity: 15, fitness: 1.2287874221801758, equations: [y1, -1.23*a0 - 3.7*u0 - 2.46*y1, a1]
# Complexity: 17, fitness: 1.228170394897461, equations: [-0.135, -2.46*u0 - 1.23*y0 - 3.7*y1, 2*a1]
# Complexity: 19, fitness: 1.2277923822402954, equations: [1.9*u0, -2.46*u0 - 1.23*y0 - 2.46*y1, 2*a1]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 29
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 13, fitness: 1.228823184967041, equations: [u0, -2.46*u0 - 1.23*y0 - 2.46*y1, a1]
# Complexity: 15, fitness: 1.2287874221801758, equations: [y1, -1.23*a0 - 3.7*u0 - 2.46*y1, a1]
# Complexity: 17, fitness: 1.228170394897461, equations: [-0.135, -2.46*u0 - 1.23*y0 - 3.7*y1, 2*a1]
# Complexity: 19, fitness: 1.2277923822402954, equations: [1.9*u0, -2.46*u0 - 1.23*y0 - 2.46*y1, 2*a1]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 30
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 13, fitness: 1.228823184967041, equations: [u0, -2.46*u0 - 1.23*y0 - 2.46*y1, a1]
# Complexity: 15, fitness: 1.2287874221801758, equations: [y1, -1.23*a0 - 3.7*u0 - 2.46*y1, a1]
# Complexity: 17, fitness: 1.228170394897461, equations: [-0.135, -2.46*u0 - 1.23*y0 - 3.7*y1, 2*a1]
# Complexity: 19, fitness: 1.2277923822402954, equations: [1.9*u0, -2.46*u0 - 1.23*y0 - 2.46*y1, 2*a1]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 31
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 13, fitness: 1.228823184967041, equations: [u0, -2.46*u0 - 1.23*y0 - 2.46*y1, a1]
# Complexity: 15, fitness: 1.2287874221801758, equations: [y1, -1.23*a0 - 3.7*u0 - 2.46*y1, a1]
# Complexity: 17, fitness: 1.228170394897461, equations: [-0.135, -2.46*u0 - 1.23*y0 - 3.7*y1, 2*a1]
# Complexity: 19, fitness: 1.2277923822402954, equations: [1.9*u0, -2.46*u0 - 1.23*y0 - 2.46*y1, 2*a1]
# Complexity: 21, fitness: 1.2079036235809326, equations: [-0.000695*a0 - 9.41e-5, 0.793/y0, -0.227*a0*a1 + 0.0621]
# In generation 32
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 13, fitness: 1.228823184967041, equations: [u0, -2.46*u0 - 1.23*y0 - 2.46*y1, a1]
# Complexity: 15, fitness: 1.2287874221801758, equations: [y1, -1.23*a0 - 3.7*u0 - 2.46*y1, a1]
# Complexity: 17, fitness: 1.228170394897461, equations: [-0.135, -2.46*u0 - 1.23*y0 - 3.7*y1, 2*a1]
# Complexity: 19, fitness: 1.2274214029312134, equations: [1.02, -2.46*u0 - 1.23*y0 - 2.46*y1, 4*a1]
# Complexity: 21, fitness: 1.1842902898788452, equations: [0.000695*a0 - 9.41e-5, 0.793/y0, 0.143*a0*a1 + 0.0621]
# In generation 33
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 13, fitness: 1.228823184967041, equations: [u0, -2.46*u0 - 1.23*y0 - 2.46*y1, a1]
# Complexity: 15, fitness: 1.2287874221801758, equations: [y1, -1.23*a0 - 3.7*u0 - 2.46*y1, a1]
# Complexity: 17, fitness: 1.228170394897461, equations: [-0.135, -2.46*u0 - 1.23*y0 - 3.7*y1, 2*a1]
# Complexity: 19, fitness: 1.2274214029312134, equations: [1.02, -2.46*u0 - 1.23*y0 - 2.46*y1, 4*a1]
# Complexity: 21, fitness: 1.1842902898788452, equations: [0.000695*a0 - 9.41e-5, 0.793/y0, 0.143*a0*a1 + 0.0621]
# In generation 34
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 13, fitness: 1.228823184967041, equations: [u0, -2.46*u0 - 1.23*y0 - 2.46*y1, a1]
# Complexity: 15, fitness: 1.2277923822402954, equations: [1.58e-5, -2.46*u0 - 1.23*y0 - 2.46*y1, 2*a1]
# Complexity: 19, fitness: 1.2274214029312134, equations: [1.02, -2.46*u0 - 1.23*y0 - 2.46*y1, 4*a1]
# Complexity: 21, fitness: 1.1652449369430542, equations: [0.0252 - 0.175*a0, 0.793/y0, 0.00888*a0*a1]
# In generation 35
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 9, fitness: 1.1620903015136719, equations: [-0.000112, 1.1/y0, 0.00613*a1 + 0.0621]
# In generation 36
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 5, fitness: 1.318896770477295, equations: [-0.000112, 1.36/y0, 0.0338]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 9, fitness: 1.1620903015136719, equations: [-0.000112, 1.1/y0, 0.00613*a1 + 0.0621]
# In generation 37
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 5, fitness: 1.318896770477295, equations: [-0.000112, 1.36/y0, 0.0338]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 9, fitness: 1.1620903015136719, equations: [-0.000112, 1.1/y0, 0.00613*a1 + 0.0621]
# In generation 38
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 5, fitness: 1.318896770477295, equations: [-0.000112, 1.36/y0, 0.0338]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 9, fitness: 1.1620903015136719, equations: [-0.000112, 1.1/y0, 0.00613*a1 + 0.0621]
# In generation 39
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 5, fitness: 1.318896770477295, equations: [-0.000112, 1.36/y0, 0.0338]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 9, fitness: 1.1620903015136719, equations: [-0.000112, 1.1/y0, 0.00613*a1 + 0.0621]
# In generation 40
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 5, fitness: 1.318896770477295, equations: [-0.000112, 1.36/y0, 0.0338]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 9, fitness: 1.1620903015136719, equations: [-0.000112, 1.1/y0, 0.00613*a1 + 0.0621]
# In generation 41
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 5, fitness: 1.318896770477295, equations: [-0.000112, 1.36/y0, 0.0338]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 9, fitness: 1.1620903015136719, equations: [-0.000112, 1.1/y0, 0.00613*a1 + 0.0621]
# In generation 42
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 5, fitness: 1.318896770477295, equations: [-0.000112, 1.36/y0, 0.0338]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 9, fitness: 1.1620903015136719, equations: [-0.309, 1.1/y0, 0.00613*a1 + 0.0621]
# In generation 43
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 5, fitness: 1.318896770477295, equations: [-0.000112, 1.36/y0, 0.0338]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 9, fitness: 1.1620903015136719, equations: [-0.309, 1.1/y0, 0.00613*a1 + 0.0621]
# In generation 44
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 5, fitness: 1.318896770477295, equations: [-0.000112, 1.36/y0, 0.0338]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 9, fitness: 1.1620903015136719, equations: [-0.309, 1.1/y0, 0.00613*a1 + 0.0621]
# In generation 45
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 5, fitness: 1.318896770477295, equations: [-0.000112, 1.36/y0, 0.0338]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 9, fitness: 1.1620903015136719, equations: [-0.309, 1.1/y0, 0.00613*a1 + 0.0621]
# In generation 46
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 5, fitness: 1.318896770477295, equations: [-0.000112, 1.36/y0, 0.0338]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 9, fitness: 1.1620903015136719, equations: [-0.309, 1.1/y0, 0.00613*a1 + 0.0621]
# In generation 47
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 5, fitness: 1.318896770477295, equations: [-0.000112, 1.36/y0, 0.0338]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 9, fitness: 1.1620903015136719, equations: [-0.309, 1.1/y0, 0.00613*a1 + 0.0621]
# In generation 48
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 5, fitness: 1.318896770477295, equations: [-0.000112, 1.36/y0, 0.0338]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 9, fitness: 1.1620903015136719, equations: [-0.574, 1.1/y0, 0.00613*a1 + 0.0621]
# In generation 49
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 5, fitness: 1.318896770477295, equations: [-0.000112, 1.36/y0, 0.0338]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 9, fitness: 1.1620903015136719, equations: [-0.574, 1.1/y0, 0.00613*a1 + 0.0621]
# In generation 50
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 5, fitness: 1.318896770477295, equations: [-0.000112, 1.36/y0, 0.0338]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 9, fitness: 1.1620903015136719, equations: [-1.77, 1.1/y0, 0.00613*a1 + 0.0621]
# Final pareto front:
# Complexity: 3, fitness: 1.3188995122909546, equations: [-3.03, 1.73, 0.0328]
# Complexity: 5, fitness: 1.318896770477295, equations: [-0.000112, 1.36/y0, 0.0338]
# Complexity: 7, fitness: 1.229701280593872, equations: [a0, u0 + y1, -2.73*a1]
# Complexity: 9, fitness: 1.1620903015136719, equations: [-1.77, 1.1/y0, 0.00613*a1 + 0.0621]

# %%
# Get the best solution from the pareto front
best_idx = jnp.argmin(jnp.array(strategy.pareto_front[0]))
best_fitness = strategy.pareto_front[0][best_idx]  # Best fitness
best_solution = strategy.pareto_front[1][best_idx]  # Best solution
best_solution_str = strategy.expression_to_string(best_solution)

print(f"Final best fitness: {best_fitness}")
print(f"Final best solution: {best_solution_str}")

os.makedirs(save_path, exist_ok=True)
np.save(f'{save_path}/best_fitnesses.npy', best_fitnesses)
np.save(f'{save_path}/best_solutions.npy', strategy.pareto_front[1])
# Out:
# Final best fitness: 1.1620903015136719
# Final best solution: [-1.77, 1.1/y0, 0.00613*a1 + 0.0621]

# %%
learn_condition = 2
feedback_fn = distance_feedback
sign_estimation = False

env = HarmonicOscillator(process_noise=args["process_noise"], obs_noise=args["obs_noise"])
test_data = get_data(jr.PRNGKey(0), env, 4, 0.2, 40.0, args["param_setting"], n_jumps=0, init_pos_near=init_pos_near)
x0s, ts, targets, noise_key, params = test_data
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.3),
    ("/", lambda x, y: jnp.divide(x, y), 2, 0.1)
]
strategy, fitness_function = get_strategy(env, learn_condition, feedback_fn, sign_estimation, operator_list, 0.05, device=device)
best_fitness, best_model = validate(np.load(f'{save_path}/best_solutions.npy'), strategy, test_data)
print(f"Best fitness on test data: {best_fitness}")
# Out:
# Input data should be formatted as: ['y0', 'y1', 'a0', 'a1', 'u0', 'e'].
# Best fitness on test data: 0.25336945056915283

# %%
xs, ys, us, activities, fitness, fbs = jax.vmap(fitness_function.evaluate_trajectory, in_axes=[
    None, 0, None, 0, 0, 0, None])(best_model, *test_data, strategy.tree_evaluator)

fig, ax = plt.subplots(2, 2, figsize=(9.5, 5))
ax = ax.ravel()
for i in range(4):
    ax[i].plot(ts, xs[i, :, 0], label="$x_0$", color="#1f77b4", linewidth=1.8)
    ax[i].plot(ts, xs[i, :, 1], label="$x_1$", color="#ff7f0e", linewidth=1.8)
    ax[i].plot(ts, ys[i, :, 0], alpha=0.2, color="#1f77b4")
    ax[i].plot(ts, ys[i, :, 1], alpha=0.2, color="#ff7f0e")
    ax[i].plot(ts, us[i, :], label="$u$", color="#2ca02c", linewidth=1.5)
    ax[i].plot(ts, fbs[i, :], label="$r$", color="#d62728", linewidth=1.2)
    ax[i].plot(ts, targets[i, :, 0], '--k', lw=2)
    ax[i].set_xlabel("Time")
    ax[i].legend(loc="upper right", fontsize=9, frameon=False, ncols=2)
    ax[i].spines[['right', 'top']].set_visible(False)
    ax[i].autoscale_view(scalex=True, scaley=True)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
