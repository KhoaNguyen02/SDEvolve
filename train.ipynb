# %%
import os
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count=10'

import jax
import jax.random as jr
import jax.numpy as jnp
from utils import *
from main import run_experiment
from environments.harmonic_oscillator import HarmonicOscillator
import numpy as np
import matplotlib.pyplot as plt

device = jax.devices()[0].platform
print(f"Using device: {device}")
# Out:
# These device(s) are detected:  [CpuDevice(id=0), CpuDevice(id=1), CpuDevice(id=2), CpuDevice(id=3), CpuDevice(id=4), CpuDevice(id=5), CpuDevice(id=6), CpuDevice(id=7), CpuDevice(id=8), CpuDevice(id=9)]
# Using device: cpu

# %%
def distance_feedback(x, target):
    err = x[0] - target
    return 0.5 * err**2

def direction_feedback(x, target):
    return target - x[0]

args = {
    "param_setting": "constant",
    "batch_size": 16,
    "n_obs": 2,
    "process_noise": 0.05,
    "obs_noise": 0.3,
    "num_generations": 50,
    "population_size": 100,
    "num_populations": 10
}

save_path = 'results/harmonic_oscillator/full_obs/noisy_obs'
os.makedirs(save_path, exist_ok=True)

learn_condition = 3
feedback_fn = None
sign_estimation = False

# %%
strategy, best_fitnesses = run_experiment(args, learn_condition, feedback_fn, sign_estimation, save_path=save_path, device=device)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'a0', 'a1', 'u0'].
# Compiling code for evaluation and evolution...
# Finished compilation in 38.64 seconds
# In generation 1
# Complexity: 5, fitness: 4.308530330657959, equations: [0.379, -0.332*a1, 0.594]
# Complexity: 7, fitness: 3.9842798709869385, equations: [0.342, y1 + 0.307, 0.0707]
# Complexity: 15, fitness: 3.4609060287475586, equations: [a1*(u0 + 0.826) - y0 + y1 - 1.92, 1.04, -0.297*a0]
# Complexity: 19, fitness: 2.8786826133728027, equations: [u0 + 0.425*y1, u0**2*y0 + 0.134, 1.48 - 1.97*a0]
# In generation 2
# Complexity: 3, fitness: 4.174884796142578, equations: [0.342, 2.43, -0.315]
# Complexity: 5, fitness: 3.9845118522644043, equations: [y0, 1.07*a1, 0.0957]
# Complexity: 7, fitness: 3.9842798709869385, equations: [0.342, y1 + 0.307, 0.0707]
# Complexity: 13, fitness: 2.855334520339966, equations: [a0*(1.09 - u0), -1.23*u0 - 1.23*y1, a1 - 0.135]
# Complexity: 27, fitness: 2.850987195968628, equations: [2*u0 + y1 - 0.091, -0.586*a1 + 1.86*y0 + 3.92, 0.149 - a0]
# In generation 3
# Complexity: 3, fitness: 3.987309217453003, equations: [a0, 0.0362, 0.0289]
# Complexity: 5, fitness: 3.9845118522644043, equations: [0.524, a1 - 1.07, 0.0957]
# Complexity: 7, fitness: 3.9842798709869385, equations: [0.342, y1 + 0.307, 0.0707]
# Complexity: 9, fitness: 3.894151449203491, equations: [y0, -0.134*y1 - 0.00293, a1 - 0.134]
# Complexity: 13, fitness: 2.855334520339966, equations: [a0*(1.09 - u0), -1.23*u0 - 1.23*y1, a1 - 0.135]
# Complexity: 15, fitness: 2.854032278060913, equations: [-1.49*a0 - 1.57*y1, 0.763*a1 + 1.73, a0]
# Complexity: 19, fitness: 2.850987195968628, equations: [2*u0 + y1 - 0.091, -2.31, 0.149 - a0]
# In generation 4
# Complexity: 3, fitness: 3.9845118522644043, equations: [-0.602, -1.74, 0.0957]
# Complexity: 5, fitness: 3.9842798709869385, equations: [0.342*a0, -1.51, 0.0707]
# Complexity: 9, fitness: 2.8491647243499756, equations: [-1.66*a0 - 1.57*y1, -0.115, a0]
# In generation 5
# Complexity: 3, fitness: 3.9845118522644043, equations: [-0.602, -1.74, 0.0957]
# Complexity: 5, fitness: 3.9842474460601807, equations: [2*a1, -1.51, 0.0724]
# Complexity: 7, fitness: 3.984189033508301, equations: [2.92*y0/a0, a1, 0.0784]
# Complexity: 9, fitness: 2.8491647243499756, equations: [-1.66*a0 - 1.57*y1, -0.115, a0]
# Complexity: 25, fitness: 2.845197916030884, equations: [2*u0 + y1, u0**2*(y1 - 0.283) + 0.134, -1.97*a0]
# In generation 6
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, a1, 0.0784]
# Complexity: 7, fitness: 3.9838979244232178, equations: [u0 + 0.85, y1, -0.295*a1]
# Complexity: 9, fitness: 2.8491647243499756, equations: [-1.66*a0 - 1.57*y1, -0.115, a0]
# Complexity: 19, fitness: 2.845197916030884, equations: [2*u0 + y1, 0.134 - 1.42*u0**2, -1.97*a0]
# In generation 7
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 7, fitness: 2.8689680099487305, equations: [-0.849*a0 - 0.849*y1, 0.875, a0]
# Complexity: 9, fitness: 2.8491647243499756, equations: [-1.66*a0 - 1.57*y1, -0.115, a0]
# Complexity: 17, fitness: 2.8453469276428223, equations: [-1.32, a1*u0 - u0 - y1 + 0.0903, 2*a1 + 1.12]
# Complexity: 19, fitness: 2.845197916030884, equations: [2*u0 + y1, 0.134 - 1.42*u0**2, -1.97*a0]
# In generation 8
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 7, fitness: 2.8537402153015137, equations: [a0, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8491647243499756, equations: [-1.66*a0 - 1.57*y1, -0.115, a0]
# Complexity: 17, fitness: 2.8453469276428223, equations: [-1.32, a1*u0 - u0 - y1 + 0.0903, 2*a1 + 1.12]
# Complexity: 19, fitness: 2.845197916030884, equations: [2*u0 + y1, 0.134 - 1.42*u0**2, -1.97*a0]
# In generation 9
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 7, fitness: 2.8537402153015137, equations: [a0, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8491647243499756, equations: [-1.66*a0 - 1.57*y1, -0.115, a0]
# Complexity: 17, fitness: 2.8453469276428223, equations: [-1.32, a1*u0 - u0 - y1 + 0.0903, 2*a1 + 1.12]
# Complexity: 19, fitness: 2.845197916030884, equations: [2*u0 + y1, 0.134 - 1.42*u0**2, -1.97*a0]
# In generation 10
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8491647243499756, equations: [-1.66*a0 - 1.57*y1, -0.115, a0]
# Complexity: 15, fitness: 2.848971366882324, equations: [2*u0 + y1 - 0.091, 0.401*a1, -1.1*a0]
# Complexity: 17, fitness: 2.845197916030884, equations: [2*u0 + y1, u0 + 0.785*y1 - 0.167, -1.97*a0]
# Complexity: 19, fitness: 2.844486951828003, equations: [4*u0 + 2*y1 - 0.091, 0.898, -1.09*a0]
# Complexity: 21, fitness: 2.8437325954437256, equations: [-1.84*u0, -1.11*a1 - u0 - y1 + 0.0903, 2*a1 + 0.0483]
# In generation 11
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8491647243499756, equations: [-1.66*a0 - 1.57*y1, -0.115, a0]
# Complexity: 11, fitness: 2.845197916030884, equations: [2*u0 + y1, -0.367*y0, -1.97*a0]
# Complexity: 13, fitness: 2.841254949569702, equations: [a0, -1.23*a1 - 1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 27, fitness: 2.831794023513794, equations: [u0*(u0 + y1 - 0.091) + 2*u0 + y1, -1.36, -2.25*a0 - 0.542]
# In generation 12
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8491647243499756, equations: [-1.66*a0 - 1.57*y1, -0.115, a0]
# Complexity: 11, fitness: 2.8449997901916504, equations: [y1, -2.46*u0 - 1.23*y1, 2*a1]
# Complexity: 13, fitness: 2.841254949569702, equations: [a0, -1.23*a1 - 1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 27, fitness: 2.8308138847351074, equations: [u0*(u0 + y1 - 0.091) + 2*u0 + y1, 0.693*y1, -2*a0 - 0.18]
# In generation 13
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8477649688720703, equations: [1.90, -2.46*u0 - 1.23*y1, a1]
# Complexity: 11, fitness: 2.8449997901916504, equations: [0.583, -2.46*u0 - 1.23*y1, 2*a1]
# Complexity: 13, fitness: 2.841254949569702, equations: [a0, -1.23*a1 - 1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 25, fitness: 2.836887836456299, equations: [u0*(2*y1 + 1.48) + 2*u0 + y1, 0.516, -2.25*a0 - 0.542]
# Complexity: 27, fitness: 2.8308138847351074, equations: [u0*(u0 + y1 - 0.091) + 2*u0 + y1, 0.693*y1, -2*a0 - 0.18]
# In generation 14
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8477649688720703, equations: [-17.7, -2.46*u0 - 1.23*y1, a1]
# Complexity: 11, fitness: 2.8449997901916504, equations: [0.00401, -2.46*u0 - 1.23*y1, 2*a1]
# Complexity: 13, fitness: 2.841254949569702, equations: [a0, -1.23*a1 - 1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 23, fitness: 2.8237757682800293, equations: [u0*(y1 + 0.0337) + 2*u0 + y1, 0.516, -2.25*a0 - 0.542]
# In generation 15
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8477649688720703, equations: [-17.7, -2.46*u0 - 1.23*y1, a1]
# Complexity: 11, fitness: 2.8449997901916504, equations: [0.00401, -2.46*u0 - 1.23*y1, 2*a1]
# Complexity: 13, fitness: 2.841254949569702, equations: [a0, -1.23*a1 - 1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 17, fitness: 2.8320040702819824, equations: [u0*(y1 + 0.0337) + 2*u0 + y1, -1.84, 0.98 - a0]
# Complexity: 23, fitness: 2.8237757682800293, equations: [u0*(y1 + 0.0337) + 2*u0 + y1, 0.516, -2.25*a0 - 0.542]
# In generation 16
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8477649688720703, equations: [-17.7, -2.46*u0 - 1.23*y1, a1]
# Complexity: 11, fitness: 2.8434600830078125, equations: [-2.77*a0 - 1.57*y1, -1.39, a0]
# Complexity: 13, fitness: 2.841254949569702, equations: [1.09, -3.7*u0 - 2.46*y1, a1]
# Complexity: 17, fitness: 2.8305253982543945, equations: [u0*(y1 - 0.226) + 2*u0 + y1, 0.463, 0.865 - a0]
# Complexity: 23, fitness: 2.8237757682800293, equations: [u0*(y1 + 0.0337) + 2*u0 + y1, -0.837, -2.25*a0 - 0.542]
# In generation 17
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8477649688720703, equations: [-17.7, -2.46*u0 - 1.23*y1, a1]
# Complexity: 11, fitness: 2.8434600830078125, equations: [-2.77*a0 - 1.57*y1, -1.39, a0]
# Complexity: 13, fitness: 2.841254949569702, equations: [1.09, -3.7*u0 - 2.46*y1, a1]
# Complexity: 15, fitness: 2.8410284519195557, equations: [a1, -1.23*a1 - 1.23*u0 - 1.23*y1, 2*a1 + 0.0196]
# Complexity: 17, fitness: 2.8256161212921143, equations: [u0*(y1 - 0.226) + 2*u0 + y1, -0.739, -a0 - 0.591]
# Complexity: 21, fitness: 2.823169231414795, equations: [33.4 - a0, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, 1.18*a1 + 0.423]
# In generation 18
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8477649688720703, equations: [-17.7, -2.46*u0 - 1.23*y1, a1]
# Complexity: 11, fitness: 2.841254949569702, equations: [y1, -1.23*a1 - 1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 15, fitness: 2.8337204456329346, equations: [u0*(y1 + 0.0674) + u0 + y1, 0.516, 0.494 - a0]
# Complexity: 17, fitness: 2.824957847595215, equations: [u0*(y1 + 0.0337) + 2*u0 + y1, 0.0337, 0.331 - a0]
# Complexity: 21, fitness: 2.823169231414795, equations: [33.4 - a0, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, 1.18*a1 + 0.423]
# In generation 19
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.847764730453491, equations: [a0, -1.23*a1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 11, fitness: 2.841254949569702, equations: [y1, -1.23*a1 - 1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 15, fitness: 2.8337204456329346, equations: [u0*(y1 + 0.0674) + u0 + y1, -0.352, 0.494 - a0]
# Complexity: 17, fitness: 2.824957847595215, equations: [u0*(y1 + 0.0337) + 2*u0 + y1, 0.0337, 0.331 - a0]
# Complexity: 19, fitness: 2.823169231414795, equations: [a0 + 22.1, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, 1.18*a1 + 0.423]
# Complexity: 23, fitness: 2.82198166847229, equations: [u0*(u0 + 2*y1) + u0 + y1, a1 - 0.515, 1.25 - 2*a0]
# In generation 20
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8458738327026367, equations: [11.6, -2.23*u0 - 1.23*y1, a1]
# Complexity: 11, fitness: 2.841254949569702, equations: [0.583, -1.23*a1 - 1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 15, fitness: 2.8337204456329346, equations: [u0*(y1 + 0.0674) + u0 + y1, -0.352, 0.494 - a0]
# Complexity: 17, fitness: 2.824957847595215, equations: [u0*(y1 + 0.0337) + 2*u0 + y1, 0.0337, 0.331 - a0]
# Complexity: 19, fitness: 2.823169231414795, equations: [a0 + 22.1, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, 1.18*a1 + 0.423]
# Complexity: 21, fitness: 2.822572946548462, equations: [u0*(y1 + 0.0337) + 2*u0 + y1, 0.207, -2*a0 - 0.18]
# Complexity: 23, fitness: 2.82198166847229, equations: [u0*(u0 + 2*y1) + u0 + y1, a1 - 0.515, 1.25 - 2*a0]
# Complexity: 25, fitness: 2.8215768337249756, equations: [u0*(u0 + 2*y1) + u0 + y1, a1 - 0.515, -2.25*a0 - 0.542]
# Complexity: 27, fitness: 2.8199656009674072, equations: [u0*(u0 + 2*y1 + 1.48) + y1, 0.380, 0.469 - 3.09*a0]
# In generation 21
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8458738327026367, equations: [11.6, -2.23*u0 - 1.23*y1, a1]
# Complexity: 11, fitness: 2.841254949569702, equations: [0.583, -1.23*a1 - 1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 13, fitness: 2.8223767280578613, equations: [0.366, -1.23*u0*y1 - 2.46*u0 - 1.23*y1, a1]
# Complexity: 17, fitness: 2.8214833736419678, equations: [33.4 - a0, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 27, fitness: 2.8196253776550293, equations: [u0*(u0 + 2*y1 + 0.109) + u0 + y1, -0.921, 1.15 - 3.09*a0]
# Complexity: 29, fitness: 2.8165900707244873, equations: [u0*(u0 + 2*y1) + u0 + y1 - 0.0316, 0.0179*y1 - 0.00924, -2.24*a0 + 0.753*a1]
# In generation 22
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.841254949569702, equations: [0.583, -1.23*a1 - 1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.821375846862793, equations: [0.713, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, 1.18*a1]
# Complexity: 21, fitness: 2.821007013320923, equations: [u0*(u0 + 2*y1 + 0.109) + u0 + y1, -0.0115, 1.14 - 2.29*a0]
# Complexity: 25, fitness: 2.819136619567871, equations: [u0*(u0 + 2*y1) + u0 + y1, a1 + 0.515, 0.894 - 2*a0]
# Complexity: 29, fitness: 2.8165900707244873, equations: [u0*(u0 + 2*y1) + u0 + y1 - 0.0316, 0.0179*y1 - 0.00924, -2.24*a0 + 0.753*a1]
# In generation 23
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.841254949569702, equations: [-1.11, -1.23*a1 - 1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.821375846862793, equations: [0.713, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, 1.18*a1]
# Complexity: 21, fitness: 2.821007013320923, equations: [u0*(u0 + 2*y1 + 0.109) + u0 + y1, -0.0115, 1.14 - 2.29*a0]
# Complexity: 25, fitness: 2.819136619567871, equations: [u0*(u0 + 2*y1) + u0 + y1, a1 + 0.515, 0.894 - 2*a0]
# Complexity: 27, fitness: 2.8147435188293457, equations: [u0*(u0 + 2*y1 - 0.0683) + u0 + y1, a0 + y1, 0.106 - 2*a0]
# In generation 24
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.841254949569702, equations: [-1.11, -1.23*a1 - 1.23*u0 - 1.23*y1, 2*a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.821375846862793, equations: [0.713, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, 1.18*a1]
# Complexity: 21, fitness: 2.8195152282714844, equations: [u0*(u0 + 2*y1) + u0 + y1 - 0.0316, -0.134*y1, -1.48*a0]
# Complexity: 25, fitness: 2.817477226257324, equations: [u0*(2*u0 + 2*y1) + u0 + y1 - 0.0316, -0.134, -2.97*a0]
# Complexity: 27, fitness: 2.8147435188293457, equations: [u0*(u0 + 2*y1 - 0.0683) + u0 + y1, a0 + y1, 0.106 - 2*a0]
# Complexity: 35, fitness: 2.8144664764404297, equations: [u0*(u0 + 2*y1) + u0 + y1, a0 + y1 + 0.515, 0.106 - 4*a0]
# In generation 25
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [0.0920, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.821375846862793, equations: [0.713, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, 1.18*a1]
# Complexity: 21, fitness: 2.819281816482544, equations: [u0*(u0 + 2*y1 + 0.109) + u0 + y1, 0.474, 0.796 - 2.09*a0]
# Complexity: 23, fitness: 2.8174421787261963, equations: [u0*(u0 + 2*y1) + u0 + y1 - 0.0316, -0.0437*a0, -1.97*a0 + a1]
# Complexity: 27, fitness: 2.8147435188293457, equations: [u0*(u0 + 2*y1 - 0.0683) + u0 + y1, a0 + 0.817, 0.106 - 2*a0]
# Complexity: 29, fitness: 2.8134260177612305, equations: [u0*(u0 + 2*y1 - 0.0683) + u0 + y1, -a1 + 2*u0 - 0.278, 0.212 - 3*a0]
# In generation 26
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [0.0920, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.821375846862793, equations: [-1.61, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, 1.18*a1]
# Complexity: 21, fitness: 2.819281816482544, equations: [u0*(u0 + 2*y1 + 0.109) + u0 + y1, 0.474, 0.796 - 2.09*a0]
# Complexity: 23, fitness: 2.80936598777771, equations: [u0*(u0 + 2*y1) + u0 + 2*y1 - 0.0316, -0.134, -3.94*a0]
# Complexity: 31, fitness: 2.8089561462402344, equations: [u0*(u0 + 2*y1) + u0 + y1 - 0.0316, 0.0185*y0 - 1.03*y1, -1.48*a0 + 0.753*a1 - 0.21]
# In generation 27
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [0.0880, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.821375846862793, equations: [-1.61, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, 1.18*a1]
# Complexity: 21, fitness: 2.819281816482544, equations: [u0*(u0 + 2*y1 + 0.109) + u0 + y1, 0.474, 0.796 - 2.09*a0]
# Complexity: 23, fitness: 2.80936598777771, equations: [u0*(u0 + 2*y1) + u0 + 2*y1 - 0.0316, -0.134, -3.94*a0]
# Complexity: 31, fitness: 2.8089561462402344, equations: [u0*(u0 + 2*y1) + u0 + y1 - 0.0316, 0.0185*y0 - 1.03*y1, -1.48*a0 + 0.753*a1 - 0.21]
# In generation 28
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [0.0880, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.821375846862793, equations: [-1.61, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, 1.18*a1]
# Complexity: 19, fitness: 2.8179495334625244, equations: [u0*(u0 + 2*y1 + 0.109) + u0 + y1, -0.0374, -1.89*a0 - a1]
# Complexity: 23, fitness: 2.80936598777771, equations: [u0*(u0 + 2*y1) + u0 + 2*y1 - 0.0316, -0.134, -3.94*a0]
# Complexity: 31, fitness: 2.8089561462402344, equations: [u0*(u0 + 2*y1) + u0 + y1 - 0.0316, 0.0185*y0 - 1.03*y1, -1.48*a0 + 0.753*a1 - 0.21]
# In generation 29
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.821375846862793, equations: [-1.61, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, 1.18*a1]
# Complexity: 19, fitness: 2.8179495334625244, equations: [u0*(u0 + 2*y1 + 0.109) + u0 + y1, -0.0374, -1.89*a0 - a1]
# Complexity: 23, fitness: 2.80936598777771, equations: [u0*(u0 + 2*y1) + u0 + 2*y1 - 0.0316, -0.134, -3.94*a0]
# Complexity: 31, fitness: 2.8089561462402344, equations: [u0*(u0 + 2*y1) + u0 + y1 - 0.0316, 0.0185*y0 - 1.03*y1, -1.48*a0 + 0.753*a1 - 0.21]
# In generation 30
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.821375846862793, equations: [-1.61, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, 1.18*a1]
# Complexity: 19, fitness: 2.8179495334625244, equations: [u0*(u0 + 2*y1 + 0.109) + u0 + y1, -0.0374, -1.89*a0 - a1]
# Complexity: 21, fitness: 2.8149282932281494, equations: [u0*(u0 + 2*y1) + 2*u0 + 2*y1, -0.424, -1.32*a0]
# Complexity: 23, fitness: 2.80936598777771, equations: [u0*(u0 + 2*y1) + u0 + 2*y1 - 0.0316, -0.134, -3.94*a0]
# Complexity: 31, fitness: 2.8046185970306396, equations: [u0*(u0 + 2*y1) + u0 + y1 - 0.0316, 0.218*y0 - 1.03*y1, -1.48*a0 + 0.753*a1 - 0.21]
# In generation 31
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8149282932281494, equations: [u0*(u0 + 2*y1) + 2*u0 + 2*y1, -0.424, -1.32*a0]
# Complexity: 23, fitness: 2.80936598777771, equations: [u0*(u0 + 2*y1) + u0 + 2*y1 - 0.0316, -0.134, -3.94*a0]
# Complexity: 31, fitness: 2.8046185970306396, equations: [u0*(u0 + 2*y1) + u0 + y1 - 0.0316, 0.218*y0 - 1.03*y1, -1.48*a0 + 0.753*a1 - 0.21]
# Complexity: 35, fitness: 2.7948410511016846, equations: [a1*(y1 + 0.477) + u0 + y1 - 0.0316, -1.03*y1*(0.148 - 0.00247*y0), -2.97*a0]
# In generation 32
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8537402153015137, equations: [1.09, -1.33*u0 - 1.33*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8149282932281494, equations: [u0*(u0 + 2*y1) + 2*u0 + 2*y1, -0.424, -1.32*a0]
# Complexity: 23, fitness: 2.80936598777771, equations: [u0*(u0 + 2*y1) + u0 + 2*y1 - 0.0316, -0.134, -3.94*a0]
# Complexity: 31, fitness: 2.8046185970306396, equations: [u0*(u0 + 2*y1) + u0 + y1 - 0.0316, 0.218*y0 - 1.03*y1, -1.48*a0 + 0.753*a1 - 0.21]
# Complexity: 35, fitness: 2.7948410511016846, equations: [a1*(y1 + 0.477) + u0 + y1 - 0.0316, -1.03*y1*(0.148 - 0.00247*y0), -2.97*a0]
# In generation 33
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8499133586883545, equations: [-3.64, -2.0*u0 - 2.0*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8149282932281494, equations: [u0*(u0 + 2*y1) + 2*u0 + 2*y1, -0.424, -1.32*a0]
# Complexity: 23, fitness: 2.80936598777771, equations: [u0*(u0 + 2*y1) + u0 + 2*y1 - 0.0316, -0.134, -3.94*a0]
# Complexity: 31, fitness: 2.8046185970306396, equations: [u0*(u0 + 2*y1) + u0 + y1 - 0.0316, 0.218*y0 - 1.03*y1, -1.48*a0 + 0.753*a1 - 0.21]
# Complexity: 35, fitness: 2.7948410511016846, equations: [a1*(y1 + 0.477) + u0 + y1 - 0.0316, -1.03*y1*(0.148 - 0.00247*y0), -2.97*a0]
# In generation 34
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8499133586883545, equations: [-3.64, -2.0*u0 - 2.0*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8149282932281494, equations: [u0*(u0 + 2*y1) + 2*u0 + 2*y1, -0.424, -1.32*a0]
# Complexity: 23, fitness: 2.80936598777771, equations: [u0*(u0 + 2*y1) + u0 + 2*y1 - 0.0316, -0.134, -3.94*a0]
# Complexity: 29, fitness: 2.805927276611328, equations: [u0*(u0 + 2*y1) + y1 - 0.0316, -1.03*u0 + 0.218*y0, -1.48*a0 + 0.753*a1 - 0.21]
# Complexity: 31, fitness: 2.8046185970306396, equations: [u0*(u0 + 2*y1) + u0 + y1 - 0.0316, 0.218*y0 - 1.03*y1, -1.48*a0 + 0.753*a1 - 0.21]
# Complexity: 33, fitness: 2.796260118484497, equations: [a1*(y1 + 0.477) + u0 + y1 - 0.0316, -1.03*y1*(0.148 - 0.00247*y0), 0.223 - 1.48*a0]
# Complexity: 35, fitness: 2.7948410511016846, equations: [a1*(y1 + 0.477) + u0 + y1 - 0.0316, -1.03*y1*(0.148 - 0.00247*y0), -2.97*a0]
# In generation 35
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8499133586883545, equations: [-3.64, -2.0*u0 - 2.0*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8149282932281494, equations: [u0*(u0 + 2*y1) + 2*u0 + 2*y1, -0.424, -1.32*a0]
# Complexity: 23, fitness: 2.80936598777771, equations: [u0*(u0 + 2*y1) + u0 + 2*y1 - 0.0316, -0.134, -3.94*a0]
# Complexity: 29, fitness: 2.805927276611328, equations: [u0*(u0 + 2*y1) + y1 - 0.0316, -1.03*u0 + 0.218*y0, -1.48*a0 + 0.753*a1 - 0.21]
# Complexity: 31, fitness: 2.8046185970306396, equations: [u0*(u0 + 2*y1) + u0 + y1 - 0.0316, 0.218*y0 - 1.03*y1, -1.48*a0 + 0.753*a1 - 0.21]
# Complexity: 33, fitness: 2.796260118484497, equations: [a1*(y1 + 0.477) + u0 + y1 - 0.0316, -1.03*y1*(0.148 - 0.00247*y0), 0.223 - 1.48*a0]
# Complexity: 35, fitness: 2.794642686843872, equations: [a1*(y1 + 0.477) + u0 + y1 - 0.0316, -1.03*y1*(0.148 - 0.00247*y0), 0.316 - 2.24*a0]
# In generation 36
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8499133586883545, equations: [-3.64, -2.0*u0 - 2.0*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8149282932281494, equations: [u0*(u0 + 2*y1) + 2*u0 + 2*y1, -0.424, -1.32*a0]
# Complexity: 23, fitness: 2.80936598777771, equations: [u0*(u0 + 2*y1) + u0 + 2*y1 - 0.0316, -0.134, -3.94*a0]
# Complexity: 25, fitness: 2.79260516166687, equations: [u0*(u0 + y1)*(u0 + y1 + 0.233) + y1 - 0.0316, 0.00379, -2.97*a0 + a1 + 0.208]
# Complexity: 29, fitness: 2.7914156913757324, equations: [u0*(u0 + 2*y1 + 1.48) + y1, a0 + 0.523*a1, -2.09*a0 - a1 - 0.00177]
# In generation 37
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8499133586883545, equations: [-3.64, -2.0*u0 - 2.0*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8149282932281494, equations: [u0*(u0 + 2*y1) + 2*u0 + 2*y1, -0.424, -1.32*a0]
# Complexity: 23, fitness: 2.80936598777771, equations: [u0*(u0 + 2*y1) + u0 + 2*y1 - 0.0316, -0.134, -3.94*a0]
# Complexity: 25, fitness: 2.79260516166687, equations: [u0*(u0 + y1)*(u0 + y1 + 0.233) + y1 - 0.0316, 0.00379, -2.97*a0 + a1 + 0.208]
# Complexity: 29, fitness: 2.7914156913757324, equations: [u0*(u0 + 2*y1 + 1.48) + y1, a0 + 0.523*a1, -2.09*a0 - a1 - 0.00177]
# Complexity: 31, fitness: 2.661491870880127, equations: [-u0*(u0 + 2*y1) + u0 + y1, 2*y1 - 1.69, a0*(a0 - 0.711) - 2*a0]
# In generation 38
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8499133586883545, equations: [-3.64, -2.0*u0 - 2.0*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8149282932281494, equations: [u0*(u0 + 2*y1) + 2*u0 + 2*y1, -0.424, -1.32*a0]
# Complexity: 23, fitness: 2.80936598777771, equations: [u0*(u0 + 2*y1) + u0 + 2*y1 - 0.0316, -0.134, -3.94*a0]
# Complexity: 25, fitness: 2.789750814437866, equations: [u0*(u0 + y1)*(u0 + y1 + 0.233) + y1 - 0.0316, 0.00379, -2.97*a0 + a1 - 0.208]
# Complexity: 31, fitness: 2.661491870880127, equations: [-u0*(u0 + 2*y1) + u0 + y1, 2*y1 - 1.69, a0*(a0 - 0.711) - 2*a0]
# In generation 39
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8499133586883545, equations: [-3.64, -2.0*u0 - 2.0*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8149282932281494, equations: [u0*(u0 + 2*y1) + 2*u0 + 2*y1, -0.424, -1.32*a0]
# Complexity: 23, fitness: 2.80936598777771, equations: [u0*(u0 + 2*y1) + u0 + 2*y1 - 0.0316, -0.134, -3.94*a0]
# Complexity: 25, fitness: 2.789750814437866, equations: [u0*(u0 + y1)*(u0 + y1 + 0.233) + y1 - 0.0316, 0.00379, -2.97*a0 + a1 - 0.208]
# Complexity: 31, fitness: 2.661491870880127, equations: [-u0*(u0 + 2*y1) + u0 + y1, 2*y1 - 1.69, a0*(a0 - 0.711) - 2*a0]
# In generation 40
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8499133586883545, equations: [-3.64, -2.0*u0 - 2.0*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8149282932281494, equations: [u0*(u0 + 2*y1) + 2*u0 + 2*y1, -0.424, -1.32*a0]
# Complexity: 23, fitness: 2.80936598777771, equations: [u0*(u0 + 2*y1) + u0 + 2*y1 - 0.0316, -0.134, -3.94*a0]
# Complexity: 25, fitness: 2.490968704223633, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 - 0.971*a1]
# In generation 41
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8499133586883545, equations: [-3.64, -2.0*u0 - 2.0*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8149282932281494, equations: [u0*(u0 + 2*y1) + 2*u0 + 2*y1, -0.424, -1.32*a0]
# Complexity: 23, fitness: 2.809311628341675, equations: [u0*(u0 + 2*y1) + 0.502*u0 + y1 - 0.0316, -1.03*a0 - 0.769, -1.97*a0]
# Complexity: 25, fitness: 2.490968704223633, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 - 0.971*a1]
# In generation 42
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8499133586883545, equations: [-3.64, -2.0*u0 - 2.0*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8149282932281494, equations: [u0*(u0 + 2*y1) + 2*u0 + 2*y1, -0.424, -1.32*a0]
# Complexity: 23, fitness: 2.809311628341675, equations: [u0*(u0 + 2*y1) + 0.502*u0 + y1 - 0.0316, -1.03*a0 - 0.769, -1.97*a0]
# Complexity: 25, fitness: 2.490968704223633, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 - 0.971*a1]
# In generation 43
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8499133586883545, equations: [-3.64, -2.0*u0 - 2.0*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8149282932281494, equations: [u0*(u0 + 2*y1) + 2*u0 + 2*y1, -0.424, -1.32*a0]
# Complexity: 23, fitness: 2.505089282989502, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 + a1 - 0.818]
# Complexity: 25, fitness: 2.490968704223633, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 - 0.971*a1]
# In generation 44
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8499133586883545, equations: [-3.64, -2.0*u0 - 2.0*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8149282932281494, equations: [u0*(u0 + 2*y1) + 2*u0 + 2*y1, -0.424, -1.32*a0]
# Complexity: 23, fitness: 2.505089282989502, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 + a1 - 0.818]
# Complexity: 25, fitness: 2.490968704223633, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 - 0.971*a1]
# In generation 45
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8499133586883545, equations: [-3.64, -2.0*u0 - 2.0*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8149282932281494, equations: [u0*(u0 + 2*y1) + 2*u0 + 2*y1, -0.424, -1.32*a0]
# Complexity: 23, fitness: 2.505089282989502, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 + a1 - 0.818]
# Complexity: 25, fitness: 2.490968704223633, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 - 0.971*a1]
# In generation 46
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8499133586883545, equations: [-3.64, -2.0*u0 - 2.0*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8149282932281494, equations: [u0*(u0 + 2*y1) + 2*u0 + 2*y1, -0.424, -1.32*a0]
# Complexity: 23, fitness: 2.505089282989502, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 + a1 - 0.818]
# Complexity: 25, fitness: 2.490968704223633, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 - 0.971*a1]
# In generation 47
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8499133586883545, equations: [-3.64, -2.0*u0 - 2.0*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8012595176696777, equations: [u0*(u0 + y1)*(u0 + y1 + 0.233) + y1, -0.498, -1.97*a0 - 0.31]
# Complexity: 23, fitness: 2.505089282989502, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 + a1 - 0.818]
# Complexity: 25, fitness: 2.490968704223633, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 - 0.971*a1]
# In generation 48
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8499133586883545, equations: [-3.64, -2.0*u0 - 2.0*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8012595176696777, equations: [u0*(u0 + y1)*(u0 + y1 + 0.233) + y1, -0.498, -1.97*a0 - 0.31]
# Complexity: 23, fitness: 2.505089282989502, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 + a1 - 0.818]
# Complexity: 25, fitness: 2.490968704223633, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 - 0.971*a1]
# In generation 49
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8499133586883545, equations: [-3.64, -2.0*u0 - 2.0*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8012595176696777, equations: [u0*(u0 + y1)*(u0 + y1 + 0.233) + y1, -0.498, -1.97*a0 - 0.31]
# Complexity: 23, fitness: 2.505089282989502, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 + a1 - 0.818]
# Complexity: 25, fitness: 2.490968704223633, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 - 0.971*a1]
# In generation 50
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8499133586883545, equations: [-3.64, -2.0*u0 - 2.0*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8012595176696777, equations: [u0*(u0 + y1)*(u0 + y1 + 0.233) + y1, -0.498, -1.97*a0 - 0.31]
# Complexity: 23, fitness: 2.505089282989502, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 + a1 - 0.818]
# Complexity: 25, fitness: 2.484712839126587, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 - 1.97*a1 - 0.617]
# Final pareto front:
# Complexity: 3, fitness: 3.984189033508301, equations: [a0, -0.0851, 0.0784]
# Complexity: 5, fitness: 3.217771053314209, equations: [y0, -2.46, 0.0659*a0]
# Complexity: 7, fitness: 2.8499133586883545, equations: [-3.64, -2.0*u0 - 2.0*y1, a1]
# Complexity: 9, fitness: 2.8451716899871826, equations: [-3.64, -4.0*u0 - 2.0*y1, a1]
# Complexity: 11, fitness: 2.828625202178955, equations: [-0.599, -1.23*u0*y1 - 1.23*u0 - 1.23*y1, a1]
# Complexity: 13, fitness: 2.8214833736419678, equations: [-2.48, -1.23*u0*y1 - 2.23*u0 - 1.23*y1, a1]
# Complexity: 15, fitness: 2.815744400024414, equations: [u0*(u0 + 2*y1) + u0 + y1, -0.134, -1.97*a0]
# Complexity: 21, fitness: 2.8012595176696777, equations: [u0*(u0 + y1)*(u0 + y1 + 0.233) + y1, -0.498, -1.97*a0 - 0.31]
# Complexity: 23, fitness: 2.505089282989502, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 + a1 - 0.818]
# Complexity: 25, fitness: 2.484712839126587, equations: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 - 1.97*a1 - 0.617]

# %%
# Get the best solution from the pareto front
best_idx = jnp.argmin(jnp.array(strategy.pareto_front[0]))
best_fitness = strategy.pareto_front[0][best_idx]  # Best fitness
best_solution = strategy.pareto_front[1][best_idx]  # Best solution
best_solution_str = strategy.expression_to_string(best_solution)

print(f"Final best fitness: {best_fitness}")
print(f"Final best solution: {best_solution_str}")

os.makedirs(save_path, exist_ok=True)
np.save(f'{save_path}/best_fitnesses.npy', best_fitnesses)
np.save(f'{save_path}/best_solutions.npy', strategy.pareto_front[1])
# Out:
# Final best fitness: 2.484712839126587
# Final best solution: [0.84*a1 + u0 + y1 - 0.0316, 0.138*y0*y1, -1.97*a0 - 1.97*a1 - 0.617]

# %%
learn_condition = 3
feedback_fn = None
sign_estimation = False

env = HarmonicOscillator(process_noise=args["process_noise"], obs_noise=args["obs_noise"])
test_data = get_data(jr.PRNGKey(10), env, 4, 0.2, 40.0, args["param_setting"], n_jumps=0)
x0s, ts, targets, noise_key, params = test_data
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.3),
    ("/", lambda x, y: jnp.divide(x, y), 2, 0.1)
]
strategy, fitness_function = get_strategy(env, learn_condition, feedback_fn, sign_estimation, operator_list, 0.05, device=device)
best_fitness, best_model = validate(np.load(f'{save_path}/best_solutions.npy'), strategy, test_data)
print(f"Best fitness on test data: {best_fitness}")
# Out:
# Input data should be formatted as: ['y0', 'y1', 'a0', 'a1', 'u0'].
# Best fitness on test data: 2.654136896133423

# %%
xs, ys, us, activities, fitness, fbs = jax.vmap(fitness_function.evaluate_trajectory, in_axes=[
    None, 0, None, 0, 0, 0, None])(best_model, *test_data, strategy.tree_evaluator)

fig, ax = plt.subplots(2, 2, figsize=(9.5, 5))
ax = ax.ravel()
for i in range(4):
    ax[i].plot(ts, xs[i, :, 0], label="$x_0$", color="#1f77b4", linewidth=1.8)
    ax[i].plot(ts, xs[i, :, 1], label="$x_1$", color="#ff7f0e", linewidth=1.8)
    ax[i].plot(ts, ys[i, :, 0], alpha=0.2, color="#1f77b4")
    ax[i].plot(ts, ys[i, :, 1], alpha=0.2, color="#ff7f0e")
    ax[i].plot(ts, us[i, :], label="$u$", color="#2ca02c", linewidth=1.5)
    # ax[i].plot(ts, fbs[i, :], label="$r$", color="#d62728", linewidth=1.2)
    ax[i].plot(ts, targets[i, :, 0], '--k', lw=2)
    ax[i].set_xlabel("Time")
    ax[i].legend(loc="upper right", fontsize=9, frameon=False, ncols=2)
    ax[i].spines[['right', 'top']].set_visible(False)
    ax[i].autoscale_view(scalex=True, scaley=True)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
